# %%
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
import pymongo
import pymysql as sql

# %%
api_key = "AIzaSyD7RFRdEvG-5pQFwBnSblRmUXtdLXbshNY"    

api_service_name = "youtube"
api_version = "v3"
client_secrets_file = "YOUR_CLIENT_SECRET_FILE.json"
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=api_key)

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')    
db = client['youtube_db']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = pymongo.MongoClient('mongodb://localhost:27017')
#       2 db = client['youtube_db']
#
# NameError: name 'pymongo' is not defined

# %%
ch_id = "UCvWBS0Vds2x3ehaw7DdEg3w"

# %%
ch_name = ""

# %%
request = youtube.channels().list(
part="snippet,contentDetails,statistics",
id=ch_id)
response = request.execute()
ch_info_from_yt = response
ch_info_from_yt
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '5byD1xqNvyvWdL5uEpZU3L_cygk',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'idqXlF_P4QemXRFGJKO2PqlmNXo',
#    'id': 'UCiSW3QmVduLq9MaInNONgWg',
#    'snippet': {'title': 'Aji Arts',
#     'description': "Hi! Nanba, I'm Ajai Kumar. Welcome to my channel.\n\nI do..\n\n1. Portraits\n2. Leaf art\n3. Caricature \n4. Book folding art\n5. Stencil art\n6. Spiral art\n\nCommission orders are taken. Message me on Instagram @ajipencilportrait \nDelivery available all over the country 🌎✈️🚚\nContact - +91 9551976271\n\nI need all you support and love ❤️ to our channel.\n\nDo Subscribe to our channel for more intersting Art videos.\n\nநன்றி!!\nகற்போம்! கற்பிப்போம்!!",
#     'customUrl': '@ajiarts638',
#     'publishedAt': '2020-07-03T04:20:21.809433Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZSFh3VNgXR23vhvio2JCcUP-qo2llPA4f5qw-KX=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZSFh3VNgXR23vhvio2JCcUP-qo2llPA4f5qw-KX=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AIf8zZSFh3VNgXR23vhvio2JCcUP-qo2llPA4f5qw-KX=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Aji Arts',
#      'description': "Hi! Nanba, I'm Ajai Kumar. Welcome to my channel.\n\nI do..\n\n1. Portraits\n2. Leaf art\n3. Caricature \n4. Book folding art\n5. Stencil art\n6. Spiral art\n\nCommission orders are taken. Message me on Instagram @ajipencilportrait \nDelivery available all over the country 🌎✈️🚚\nContact - +91 9551976271\n\nI need all you support and love ❤️ to our channel.\n\nDo Subscribe to our channel for more intersting Art videos.\n\nநன்றி!!\nகற்போம்! கற்பிப்போம்!!"},
#     'country': 'IN'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUiSW3QmVduLq9MaInNONgWg'}},
#    'statistics': {'viewCount': '859639',
#     'subscriberCount': '3450',
#     'hiddenSubscriberCount': False,
#     'videoCount': '119'}}]}

# %%
#getting and extracting channel details.
#youtube = googleapiclient.discovery.build(api_service_name, api_version,developerKey=api_key)

request = youtube.channels().list(
part="snippet,contentDetails,statistics",
id=ch_id)
response = request.execute()
ch_info_from_yt = response
#filtering channel details.
ch_name = ch_info_from_yt['items'][0]['snippet']['title']
playlist_id = ch_info_from_yt['items'][0]['contentDetails']['relatedPlaylists']['uploads']
subcription_count = ch_info_from_yt['items'][0]['statistics']['subscriberCount']
ch_view_count = ch_info_from_yt['items'][0]['statistics']['viewCount']
ch_description = ch_info_from_yt['items'][0]['snippet']['description']
total_videos = ch_info_from_yt['items'][0]['statistics']['videoCount']
ch_info_for_db = {"channel_name":ch_name,"channel_id":ch_id,"playlist_id":playlist_id,
                "subscription_count":subcription_count,"channel_viewcount":ch_view_count,
                "channel_description":ch_description,"total_videos_count":total_videos}
ch_info_for_db
# Out:
# {'channel_name': "Tharu's_passion",
#  'channel_id': 'UCvWBS0Vds2x3ehaw7DdEg3w',
#  'playlist_id': 'UUvWBS0Vds2x3ehaw7DdEg3w',
#  'subscription_count': '632000',
#  'channel_viewcount': '248751930',
#  'channel_description': 'Hii guys...\nWelcome to our channel guys\nI made all types of cakes in day by day\n\nInstagram id:https://instagram.com/tharu_passion?utm_source=qr&igshid=MzNlNGNkZWQ4Mg%3D%3D',
#  'total_videos_count': '228'}

# %%
information1 = db.channel_db
information1.insert_one(ch_info_for_db)
# Out:
# InsertOneResult(ObjectId('65c907b38f8b8931c67413f5'), acknowledged=True)

# %%
#getting playlist details.

res = youtube.channels().list(id=ch_id, 
                              part='contentDetails').execute()
playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
next_page_token = None
videos_id_list = []
while True:
    req = youtube.playlistItems().list(
    part="snippet,contentDetails",
    maxResults=50,
    playlistId=playlist_id,pageToken=next_page_token).execute()
    
    for i in range(0,len(req)):
    # Get the video ID.
        temp = req['items'][0]['snippet']['resourceId']['videoId']
        videos_id_list.append(temp)
    next_page_token = req.get('nextPageToken')     
    if next_page_token is None:
        break

# %%
videos_id_list
# Out:
# ['OMEAehSu3-g',
#  'OMEAehSu3-g',
#  'OMEAehSu3-g',
#  'OMEAehSu3-g',
#  'OMEAehSu3-g',
#  'a-I39t-d4zM',
#  'a-I39t-d4zM',
#  'a-I39t-d4zM',
#  'a-I39t-d4zM',
#  'a-I39t-d4zM',
#  'a-I39t-d4zM',
#  'iKnkB3p7oWA',
#  'iKnkB3p7oWA',
#  'iKnkB3p7oWA',
#  'iKnkB3p7oWA',
#  'iKnkB3p7oWA',
#  'iKnkB3p7oWA',
#  'Pe11ygOtskM',
#  'Pe11ygOtskM',
#  'Pe11ygOtskM',
#  'Pe11ygOtskM',
#  'Pe11ygOtskM',
#  'Pe11ygOtskM',
#  'C37h5jgau6M',
#  'C37h5jgau6M',
#  'C37h5jgau6M',
#  'C37h5jgau6M',
#  'C37h5jgau6M']

# %%
video_details = []

# %%
for i in range(0,len(videos_id_list),25):
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=','.join(videos_id_list[i:i+25]))
    video_response = request.execute()
    video_details.append(video_response)
print(video_response)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'SgTX4lBNduUQq56Nvct0NW8GceM', 'items': [{'kind': 'youtube#video', 'etag': 'nzwQEvTZtnk6Lb0_5hQNC3WwqJg', 'id': 'o_f8j1WGBhE', 'snippet': {'publishedAt': '2024-02-11T15:07:46Z', 'channelId': 'UCqFVPJDaz-ZTw0VbwBJhI2w', 'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Dheekshutimes', 'categoryId': '22', 'liveBroadcastContent': 'none', 'localized': {'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': ''}}, 'contentDetails': {'duration': 'PT52S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': False, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '27', 'favoriteCount': '0'}}, {'kind': 'youtube#video', 'etag': 'nzwQEvTZtnk6Lb0_5hQNC3WwqJg', 'id': 'o_f8j1WGBhE', 'snippet': {'publishedAt': '2024-02-11T15:07:46Z', 'channelId': 'UCqFVPJDaz-ZTw0VbwBJhI2w', 'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Dheekshutimes', 'categoryId': '22', 'liveBroadcastContent': 'none', 'localized': {'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': ''}}, 'contentDetails': {'duration': 'PT52S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': False, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '27', 'favoriteCount': '0'}}, {'kind': 'youtube#video', 'etag': 'nzwQEvTZtnk6Lb0_5hQNC3WwqJg', 'id': 'o_f8j1WGBhE', 'snippet': {'publishedAt': '2024-02-11T15:07:46Z', 'channelId': 'UCqFVPJDaz-ZTw0VbwBJhI2w', 'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/o_f8j1WGBhE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Dheekshutimes', 'categoryId': '22', 'liveBroadcastContent': 'none', 'localized': {'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'description': ''}}, 'contentDetails': {'duration': 'PT52S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': False, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '27', 'favoriteCount': '0'}}, {'kind': 'youtube#video', 'etag': 'nzwQEvTZtnk6Lb0_5hQNC3WwqJg', 'id': 'o_f8j1WGBhE', 'snippet': {'publishedAt': '2024-02-11T15:07:46Z', 'channelId': 'UCqFVPJDaz-ZTw0VbwBJhI2w', 'title': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr', 'descri ...

# %%
#getting video details.

video_info = []

for i in range(0,len(videos_id_list),25):
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=','.join(videos_id_list[i:i+25]))
    video_response = request.execute()
    video_details.append(video_response)
#print(video_response)


for i in range(0,len(video_details)):
    video_id = video_details[i]["items"][0]["id"]
    video_name = video_details[i]["items"][0]["snippet"]["title"]
    # Extract the video information
    video_description = video_details[i]["items"][0]["snippet"]["description"]
    
    published_at = video_details[i]["items"][0]["snippet"]["publishedAt"]
    thumbnail = video_details[i]["items"][0]["snippet"]["thumbnails"]["default"]["url"]
    view_count = video_details[i]["items"][0]["statistics"]["viewCount"]
    caption_status = video_details[i]["items"][0]["contentDetails"]["caption"]
    duration = video_details[i]["items"][0]["contentDetails"]["duration"]
    if 'likeCount' in video_details[i]["items"][0]["statistics"]:
        like_count = video_details[i]["items"][0]["statistics"]["likeCount"]
    favorite_count = video_details[i]["items"][0]["statistics"]["favoriteCount"]
    if 'commentCount' in video_details[i]["items"][0]["statistics"]:
        comment_count = video_details[i]["items"][0]["statistics"]["commentCount"]
    channel_name = video_details[i]["items"][0]["snippet"]["channelTitle"]
    video_info_dic = {"video_id":video_id,"video_name":video_name,
                      "channel_name":channel_name,"video_description":video_description,
                    "published_at":published_at,"thumbnail":thumbnail,
                    "caption_status":caption_status,"duration":duration,
                    "view_count":view_count,"like_count":like_count,
                    "favourite_count":favorite_count,"comment_count":comment_count,
                    }
    video_info.append(video_info_dic)
video_info
# Out:
# [{'video_id': 'OMEAehSu3-g',
#   'video_name': '😲wow what a creative one ...naane shock aayitta itha paathu ...#shorts #trending #birthday #howto',
#   'channel_name': "Tharu's_passion",
#   'video_description': '',
#   'published_at': '2024-02-10T12:30:56Z',
#   'thumbnail': 'https://i.ytimg.com/vi/OMEAehSu3-g/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT1M',
#   'view_count': '540421',
#   'like_count': '37424',
#   'favourite_count': '0',
#   'comment_count': '55'},
#  {'video_id': 'C37h5jgau6M',
#   'video_name': 'new design of redvelvet ...#trendingshorts #howto #homemade #redvelvetcake',
#   'channel_name': "Tharu's_passion",
#   'video_description': '',
#   'published_at': '2023-06-19T12:27:24Z',
#   'thumbnail': 'https://i.ytimg.com/vi/C37h5jgau6M/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT1M',
#   'view_count': '3712',
#   'like_count': '37424',
#   'favourite_count': '0',
#   'comment_count': '3'}]

# %%
information2 = db.video_db
information2.insert_many(video_info)
# Out:
# InsertManyResult([ObjectId('65c907c78f8b8931c67413f6'), ObjectId('65c907c78f8b8931c67413f7')], acknowledged=True)

# %%
comments_li = []

# %%
#getting comment details.
def comment_details(video_Id):
    comment_threads = []
    #res = youtube.channels().list(id=ch_id, 
                              #part='contentDetails').execute()
    
    try:
        next_page_token = None
        while True:
            request = youtube.commentThreads().list(
            part="snippet,replies",
            maxResults=25,
            pageToken=next_page_token,
            videoId=video_Id)
            response = request.execute()
            for cmt in response['items']:
                        data = dict(Comment_id = cmt['id'],
                                    Video_id = cmt['snippet']['videoId'],
                                    channel_name = ch_name,
                                    Comment_text = cmt['snippet']['topLevelComment']['snippet']['textDisplay'],
                                    Comment_author = cmt['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                    Comment_published_date = cmt['snippet']['topLevelComment']['snippet']['publishedAt'],
                                    Like_count = cmt['snippet']['topLevelComment']['snippet']['likeCount'],
                                    Reply_count = cmt['snippet']['totalReplyCount'])
                                    #channel_name = cmt['snippet']['title'])
                        comment_threads.append(data)
            next_page_token = response.get('nextPageToken')
            if next_page_token is None:
                break
            
    except:     
        pass 
    return comment_threads
def comments():
    com_d = []
    for i in videos_id_list:
        com_d+= comment_details(i)
    return com_d
comm_det = comments()

# %%
comm_det
# Out:
# [{'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxMYBbCTcYjAq1bWzx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice🥰',
#   'Comment_author': '@alphinanancy742',
#   'Comment_published_date': '2024-02-11T08:26:48Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxkpxIUgYdD6YafGgB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper Akka',
#   'Comment_author': '@murugesansony4005',
#   'Comment_published_date': '2024-02-11T08:18:10Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzrWyxruHB7IRAIK1d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super papa 😊😊😊',
#   'Comment_author': '@vijayalakshmimuthu6500',
#   'Comment_published_date': '2024-02-11T08:15:33Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx_U-DkofQXhHDCtEN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'New one super🎉',
#   'Comment_author': '@agalyap3131',
#   'Comment_published_date': '2024-02-10T14:34:26Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznVb_BX40QS1waHoN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 🎉🎉',
#   'Comment_author': '@user-fi5mv7fn3r',
#   'Comment_published_date': '2024-02-10T14:16:58Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxtzjnWp2IjfLK9kcN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤❤❤ super ah iruku ka',
#   'Comment_author': '@jarinabegam4302',
#   'Comment_published_date': '2024-02-10T14:10:07Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw8LHoXQbYR0JYEZft4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Carrom cake cake',
#   'Comment_author': '@user-pp4wf3qs9y',
#   'Comment_published_date': '2024-02-10T14:00:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSx0BmyKKk5T4szsB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka',
#   'Comment_author': '@Kavithajayabal',
#   'Comment_published_date': '2024-02-10T13:59:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzDr0ajJb7Ay4C6XeB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர் கிங்ஸ்',
#   'Comment_author': '@SivaKumar-rl6fe',
#   'Comment_published_date': '2024-02-10T13:56:39Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyfFNKnsCq4oUVI-qx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice❤',
#   'Comment_author': '@mahas180',
#   'Comment_published_date': '2024-02-10T13:53:06Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxpuw73FV9TeBsm7hh4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice',
#   'Comment_author': '@premagopal2699',
#   'Comment_published_date': '2024-02-10T13:41:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwoBwgB6j2sOHl1-uR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@sripriyar4071',
#   'Comment_published_date': '2024-02-10T13:40:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyl0zdZBSOW6TRY2bF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@keerthuprincess881',
#   'Comment_published_date': '2024-02-10T13:39:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwKAoGfMhVrYvLu4-p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super chess cake',
#   'Comment_author': '@priyaguru2502',
#   'Comment_published_date': '2024-02-10T13:38:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx8XcJfmuAQioewU8p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Try squareshape cake tin..',
#   'Comment_author': '@Anniepremlatha',
#   'Comment_published_date': '2024-02-10T13:35:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzT-n5IY_1V9UboA5d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '🎉🎉  Supper',
#   'Comment_author': '@haswathasri1967',
#   'Comment_published_date': '2024-02-10T13:32:20Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwq1zfX3a158dhB74t4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Very nice🎉🎉🎉🎉🎉🎉👌🏻👏👏',
#   'Comment_author': '@rrgroupsrr3819',
#   'Comment_published_date': '2024-02-10T13:30:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxHGptPW52a_ARpsSx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤🎉',
#   'Comment_author': '@kookieedits1502',
#   'Comment_published_date': '2024-02-10T13:28:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw1qa-JBc9bebco9Qp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 2 comment',
#   'Comment_author': '@asin_edit_7464',
#   'Comment_published_date': '2024-02-10T13:28:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxlCWe54HyY60-dKih4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '😊Now a days ur doing cake designs very superb 😊.... ♟️This chess cake is very fantastic♟️...... ❤😢',
#   'Comment_author': '@jeevithabujji8360',
#   'Comment_published_date': '2024-02-10T13:28:16Z',
#   'Like_count': 123,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzWotBWexw1hlaePlx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow what a work....really super ma',
#   'Comment_author': '@jacisebas7381',
#   'Comment_published_date': '2024-02-10T13:23:47Z',
#   'Like_count': 7,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyOEXFr0jUGNzC6InF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I&#39;m GM Judit polger while watching this chess cake I&#39;m  so  proud .',
#   'Comment_author': '@joshikajoshika5629',
#   'Comment_published_date': '2024-02-10T13:21:46Z',
#   'Like_count': 5,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugwdct9WVLp8tLtEmHZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sema creativity sis',
#   'Comment_author': '@sinegathirumal301',
#   'Comment_published_date': '2024-02-10T13:16:22Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxrwcgU-leBrOsT6E94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'First time pakura intha mari cake👌',
#   'Comment_author': '@priyangavinoth5643',
#   'Comment_published_date': '2024-02-10T13:14:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgymXP1X-HauBnTzRNd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Negga nalla ideavoda pandrega sis❤',
#   'Comment_author': '@rabiyaalmas5821',
#   'Comment_published_date': '2024-02-10T13:13:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzjVfGQiBvk8P1UY8N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka😊',
#   'Comment_author': '@DurgaDurga-kh6gj',
#   'Comment_published_date': '2024-02-10T13:11:39Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzFcw9iUYU4Ix1WANN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka cake varalavall',
#   'Comment_author': '@vasanthajvasantha841',
#   'Comment_published_date': '2024-02-10T13:08:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxlol4OIeih0tGKVGt4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 2 nd comment ❤ papa epdi irukanga akka i mean unga kutty thangam',
#   'Comment_author': '@SrinithiSandhiya',
#   'Comment_published_date': '2024-02-10T13:08:29Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxW7hhIdqY7Y2dmR9F4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka🎉',
#   'Comment_author': '@jeyasriSubasri-wy6te',
#   'Comment_published_date': '2024-02-10T13:08:01Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugz_GHCX65noXn-lo_N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am also chess player♟️💗',
#   'Comment_author': '@Cutei_baby_Shanu',
#   'Comment_published_date': '2024-02-10T13:07:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxO24IxF4UbcM_I-8J4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤',
#   'Comment_author': '@user-hh1qg5pt1t',
#   'Comment_published_date': '2024-02-10T13:07:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznKMIrk77BQs-BjLx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice cake',
#   'Comment_author': '@m.k.arasan956',
#   'Comment_published_date': '2024-02-10T13:06:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxnYGrz8QT-iA7ZXux4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Really super akka.....your talented 👏',
#   'Comment_author': '@jesusrajij6290',
#   'Comment_published_date': '2024-02-10T13:01:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJqUVWLZZ5MLdcb5B4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super வாழ்த்துக்கள்',
#   'Comment_author': '@bpavithra736',
#   'Comment_published_date': '2024-02-10T12:58:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJJY6AHxSKPoNpk_14AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka one cake order in Salem please. <br>Akka ok va',
#   'Comment_author': '@pro-uzumaki',
#   'Comment_published_date': '2024-02-10T12:56:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqWVxHWIFjtL5IKB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka cake 🎉',
#   'Comment_author': '@vijayenradhakrishnan6415',
#   'Comment_published_date': '2024-02-10T12:52:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzr1W63E2ov2b0Kx1p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka I love chess',
#   'Comment_author': '@sadhasivamravathisadhasiva5031',
#   'Comment_published_date': '2024-02-10T12:51:38Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwfP7IwR5lrtFO99JN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super aa irukku akka 😘 3 comment',
#   'Comment_author': '@bhavaniharini4248',
#   'Comment_published_date': '2024-02-10T12:50:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxjxvugwni-yrY1LNR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka first comment',
#   'Comment_author': '@user-tg8ir9pe5r',
#   'Comment_published_date': '2024-02-10T12:50:17Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw6Xw967e5kYJlr3jd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர்❤❤',
#   'Comment_author': '@user-sl6ms5to5b',
#   'Comment_published_date': '2024-02-10T12:47:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzIOHOIpqI9UhwUkL54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sis romba unique ah pandringa❤️...super ah iruku❤️❤️🎉<br>All the best❤️',
#   'Comment_author': '@umaghayathrii3276',
#   'Comment_published_date': '2024-02-10T12:46:51Z',
#   'Like_count': 10,
#   'Reply_count': 0},
#  {'Comment_id': 'UgztGaw6LnJG0iByDv54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka na unga thivera fan pappaoda smilekku na adimai',
#   'Comment_author': '@NarutoTamil-rw8dl',
#   'Comment_published_date': '2024-02-10T12:44:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzVXxLsBx7V9vGpWSV4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Awesome',
#   'Comment_author': '@AkilandeswariRajesh',
#   'Comment_published_date': '2024-02-10T12:44:07Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxbWd5vkRy0hDP_Qv94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka super akka',
#   'Comment_author': '@sfsameeh0449',
#   'Comment_published_date': '2024-02-10T12:43:56Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwU7mTTIRin8IBZ1YB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am a chess player but I am a small cute Girl I am studying 4th std A section',
#   'Comment_author': '@Jaigowshith2007',
#   'Comment_published_date': '2024-02-10T12:43:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyUWFprNXkIvmhV4_d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Unic super ❤❤❤❤❤❤',
#   'Comment_author': '@user-sy2sp1kw5w',
#   'Comment_published_date': '2024-02-10T12:43:02Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzd9YLAk_KsuKZnk-R4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 1st comment pin me please 😢',
#   'Comment_author': '@elongorevathi135',
#   'Comment_published_date': '2024-02-10T12:42:16Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxSH81hC7rn0P_zQwx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'யாருக்கெல்லாம் ருத்திகா பாபாவை புடிக்கும் LIKE IT❤️',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:41:00Z',
#   'Like_count': 56,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyv-GXsBWD4HRegjAx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow❤',
#   'Comment_author': '@vinnolivinnoli8300',
#   'Comment_published_date': '2024-02-10T12:40:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzClpxnTuayck8uck94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤❤',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:38:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx6NkOz2XNy3Gn7X-54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super❤❤❤',
#   'Comment_author': '@padmavathi1186',
#   'Comment_published_date': '2024-02-10T12:37:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwW4fusN1shXkAlBwp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka ❤❤',
#   'Comment_author': '@sathyapriyav9599',
#   'Comment_published_date': '2024-02-10T12:36:50Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxfZ9Zo-EYrcL0ZgPZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper 🎉',
#   'Comment_author': '@kanagap5199',
#   'Comment_published_date': '2024-02-10T12:33:19Z',
#   'Like_count': 27,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxMYBbCTcYjAq1bWzx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice🥰',
#   'Comment_author': '@alphinanancy742',
#   'Comment_published_date': '2024-02-11T08:26:48Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxkpxIUgYdD6YafGgB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper Akka',
#   'Comment_author': '@murugesansony4005',
#   'Comment_published_date': '2024-02-11T08:18:10Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzrWyxruHB7IRAIK1d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super papa 😊😊😊',
#   'Comment_author': '@vijayalakshmimuthu6500',
#   'Comment_published_date': '2024-02-11T08:15:33Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx_U-DkofQXhHDCtEN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'New one super🎉',
#   'Comment_author': '@agalyap3131',
#   'Comment_published_date': '2024-02-10T14:34:26Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznVb_BX40QS1waHoN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 🎉🎉',
#   'Comment_author': '@user-fi5mv7fn3r',
#   'Comment_published_date': '2024-02-10T14:16:58Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxtzjnWp2IjfLK9kcN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤❤❤ super ah iruku ka',
#   'Comment_author': '@jarinabegam4302',
#   'Comment_published_date': '2024-02-10T14:10:07Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw8LHoXQbYR0JYEZft4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Carrom cake cake',
#   'Comment_author': '@user-pp4wf3qs9y',
#   'Comment_published_date': '2024-02-10T14:00:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSx0BmyKKk5T4szsB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka',
#   'Comment_author': '@Kavithajayabal',
#   'Comment_published_date': '2024-02-10T13:59:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzDr0ajJb7Ay4C6XeB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர் கிங்ஸ்',
#   'Comment_author': '@SivaKumar-rl6fe',
#   'Comment_published_date': '2024-02-10T13:56:39Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyfFNKnsCq4oUVI-qx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice❤',
#   'Comment_author': '@mahas180',
#   'Comment_published_date': '2024-02-10T13:53:06Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxpuw73FV9TeBsm7hh4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice',
#   'Comment_author': '@premagopal2699',
#   'Comment_published_date': '2024-02-10T13:41:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwoBwgB6j2sOHl1-uR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@sripriyar4071',
#   'Comment_published_date': '2024-02-10T13:40:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyl0zdZBSOW6TRY2bF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@keerthuprincess881',
#   'Comment_published_date': '2024-02-10T13:39:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwKAoGfMhVrYvLu4-p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super chess cake',
#   'Comment_author': '@priyaguru2502',
#   'Comment_published_date': '2024-02-10T13:38:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx8XcJfmuAQioewU8p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Try squareshape cake tin..',
#   'Comment_author': '@Anniepremlatha',
#   'Comment_published_date': '2024-02-10T13:35:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzT-n5IY_1V9UboA5d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '🎉🎉  Supper',
#   'Comment_author': '@haswathasri1967',
#   'Comment_published_date': '2024-02-10T13:32:20Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwq1zfX3a158dhB74t4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Very nice🎉🎉🎉🎉🎉🎉👌🏻👏👏',
#   'Comment_author': '@rrgroupsrr3819',
#   'Comment_published_date': '2024-02-10T13:30:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxHGptPW52a_ARpsSx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤🎉',
#   'Comment_author': '@kookieedits1502',
#   'Comment_published_date': '2024-02-10T13:28:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw1qa-JBc9bebco9Qp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 2 comment',
#   'Comment_author': '@asin_edit_7464',
#   'Comment_published_date': '2024-02-10T13:28:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxlCWe54HyY60-dKih4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '😊Now a days ur doing cake designs very superb 😊.... ♟️This chess cake is very fantastic♟️...... ❤😢',
#   'Comment_author': '@jeevithabujji8360',
#   'Comment_published_date': '2024-02-10T13:28:16Z',
#   'Like_count': 123,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzWotBWexw1hlaePlx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow what a work....really super ma',
#   'Comment_author': '@jacisebas7381',
#   'Comment_published_date': '2024-02-10T13:23:47Z',
#   'Like_count': 7,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyOEXFr0jUGNzC6InF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I&#39;m GM Judit polger while watching this chess cake I&#39;m  so  proud .',
#   'Comment_author': '@joshikajoshika5629',
#   'Comment_published_date': '2024-02-10T13:21:46Z',
#   'Like_count': 5,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugwdct9WVLp8tLtEmHZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sema creativity sis',
#   'Comment_author': '@sinegathirumal301',
#   'Comment_published_date': '2024-02-10T13:16:22Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxrwcgU-leBrOsT6E94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'First time pakura intha mari cake👌',
#   'Comment_author': '@priyangavinoth5643',
#   'Comment_published_date': '2024-02-10T13:14:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgymXP1X-HauBnTzRNd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Negga nalla ideavoda pandrega sis❤',
#   'Comment_author': '@rabiyaalmas5821',
#   'Comment_published_date': '2024-02-10T13:13:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzjVfGQiBvk8P1UY8N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka😊',
#   'Comment_author': '@DurgaDurga-kh6gj',
#   'Comment_published_date': '2024-02-10T13:11:39Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzFcw9iUYU4Ix1WANN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka cake varalavall',
#   'Comment_author': '@vasanthajvasantha841',
#   'Comment_published_date': '2024-02-10T13:08:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxlol4OIeih0tGKVGt4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 2 nd comment ❤ papa epdi irukanga akka i mean unga kutty thangam',
#   'Comment_author': '@SrinithiSandhiya',
#   'Comment_published_date': '2024-02-10T13:08:29Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxW7hhIdqY7Y2dmR9F4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka🎉',
#   'Comment_author': '@jeyasriSubasri-wy6te',
#   'Comment_published_date': '2024-02-10T13:08:01Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugz_GHCX65noXn-lo_N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am also chess player♟️💗',
#   'Comment_author': '@Cutei_baby_Shanu',
#   'Comment_published_date': '2024-02-10T13:07:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxO24IxF4UbcM_I-8J4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤',
#   'Comment_author': '@user-hh1qg5pt1t',
#   'Comment_published_date': '2024-02-10T13:07:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznKMIrk77BQs-BjLx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice cake',
#   'Comment_author': '@m.k.arasan956',
#   'Comment_published_date': '2024-02-10T13:06:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxnYGrz8QT-iA7ZXux4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Really super akka.....your talented 👏',
#   'Comment_author': '@jesusrajij6290',
#   'Comment_published_date': '2024-02-10T13:01:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJqUVWLZZ5MLdcb5B4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super வாழ்த்துக்கள்',
#   'Comment_author': '@bpavithra736',
#   'Comment_published_date': '2024-02-10T12:58:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJJY6AHxSKPoNpk_14AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka one cake order in Salem please. <br>Akka ok va',
#   'Comment_author': '@pro-uzumaki',
#   'Comment_published_date': '2024-02-10T12:56:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqWVxHWIFjtL5IKB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka cake 🎉',
#   'Comment_author': '@vijayenradhakrishnan6415',
#   'Comment_published_date': '2024-02-10T12:52:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzr1W63E2ov2b0Kx1p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka I love chess',
#   'Comment_author': '@sadhasivamravathisadhasiva5031',
#   'Comment_published_date': '2024-02-10T12:51:38Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwfP7IwR5lrtFO99JN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super aa irukku akka 😘 3 comment',
#   'Comment_author': '@bhavaniharini4248',
#   'Comment_published_date': '2024-02-10T12:50:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxjxvugwni-yrY1LNR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka first comment',
#   'Comment_author': '@user-tg8ir9pe5r',
#   'Comment_published_date': '2024-02-10T12:50:17Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw6Xw967e5kYJlr3jd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர்❤❤',
#   'Comment_author': '@user-sl6ms5to5b',
#   'Comment_published_date': '2024-02-10T12:47:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzIOHOIpqI9UhwUkL54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sis romba unique ah pandringa❤️...super ah iruku❤️❤️🎉<br>All the best❤️',
#   'Comment_author': '@umaghayathrii3276',
#   'Comment_published_date': '2024-02-10T12:46:51Z',
#   'Like_count': 10,
#   'Reply_count': 0},
#  {'Comment_id': 'UgztGaw6LnJG0iByDv54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka na unga thivera fan pappaoda smilekku na adimai',
#   'Comment_author': '@NarutoTamil-rw8dl',
#   'Comment_published_date': '2024-02-10T12:44:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzVXxLsBx7V9vGpWSV4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Awesome',
#   'Comment_author': '@AkilandeswariRajesh',
#   'Comment_published_date': '2024-02-10T12:44:07Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxbWd5vkRy0hDP_Qv94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka super akka',
#   'Comment_author': '@sfsameeh0449',
#   'Comment_published_date': '2024-02-10T12:43:56Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwU7mTTIRin8IBZ1YB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am a chess player but I am a small cute Girl I am studying 4th std A section',
#   'Comment_author': '@Jaigowshith2007',
#   'Comment_published_date': '2024-02-10T12:43:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyUWFprNXkIvmhV4_d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Unic super ❤❤❤❤❤❤',
#   'Comment_author': '@user-sy2sp1kw5w',
#   'Comment_published_date': '2024-02-10T12:43:02Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzd9YLAk_KsuKZnk-R4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 1st comment pin me please 😢',
#   'Comment_author': '@elongorevathi135',
#   'Comment_published_date': '2024-02-10T12:42:16Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxSH81hC7rn0P_zQwx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'யாருக்கெல்லாம் ருத்திகா பாபாவை புடிக்கும் LIKE IT❤️',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:41:00Z',
#   'Like_count': 56,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyv-GXsBWD4HRegjAx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow❤',
#   'Comment_author': '@vinnolivinnoli8300',
#   'Comment_published_date': '2024-02-10T12:40:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzClpxnTuayck8uck94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤❤',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:38:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx6NkOz2XNy3Gn7X-54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super❤❤❤',
#   'Comment_author': '@padmavathi1186',
#   'Comment_published_date': '2024-02-10T12:37:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwW4fusN1shXkAlBwp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka ❤❤',
#   'Comment_author': '@sathyapriyav9599',
#   'Comment_published_date': '2024-02-10T12:36:50Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxfZ9Zo-EYrcL0ZgPZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper 🎉',
#   'Comment_author': '@kanagap5199',
#   'Comment_published_date': '2024-02-10T12:33:19Z',
#   'Like_count': 27,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxMYBbCTcYjAq1bWzx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice🥰',
#   'Comment_author': '@alphinanancy742',
#   'Comment_published_date': '2024-02-11T08:26:48Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxkpxIUgYdD6YafGgB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper Akka',
#   'Comment_author': '@murugesansony4005',
#   'Comment_published_date': '2024-02-11T08:18:10Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzrWyxruHB7IRAIK1d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super papa 😊😊😊',
#   'Comment_author': '@vijayalakshmimuthu6500',
#   'Comment_published_date': '2024-02-11T08:15:33Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx_U-DkofQXhHDCtEN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'New one super🎉',
#   'Comment_author': '@agalyap3131',
#   'Comment_published_date': '2024-02-10T14:34:26Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznVb_BX40QS1waHoN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 🎉🎉',
#   'Comment_author': '@user-fi5mv7fn3r',
#   'Comment_published_date': '2024-02-10T14:16:58Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxtzjnWp2IjfLK9kcN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤❤❤ super ah iruku ka',
#   'Comment_author': '@jarinabegam4302',
#   'Comment_published_date': '2024-02-10T14:10:07Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw8LHoXQbYR0JYEZft4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Carrom cake cake',
#   'Comment_author': '@user-pp4wf3qs9y',
#   'Comment_published_date': '2024-02-10T14:00:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSx0BmyKKk5T4szsB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka',
#   'Comment_author': '@Kavithajayabal',
#   'Comment_published_date': '2024-02-10T13:59:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzDr0ajJb7Ay4C6XeB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர் கிங்ஸ்',
#   'Comment_author': '@SivaKumar-rl6fe',
#   'Comment_published_date': '2024-02-10T13:56:39Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyfFNKnsCq4oUVI-qx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice❤',
#   'Comment_author': '@mahas180',
#   'Comment_published_date': '2024-02-10T13:53:06Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxpuw73FV9TeBsm7hh4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice',
#   'Comment_author': '@premagopal2699',
#   'Comment_published_date': '2024-02-10T13:41:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwoBwgB6j2sOHl1-uR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@sripriyar4071',
#   'Comment_published_date': '2024-02-10T13:40:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyl0zdZBSOW6TRY2bF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super',
#   'Comment_author': '@keerthuprincess881',
#   'Comment_published_date': '2024-02-10T13:39:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwKAoGfMhVrYvLu4-p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super chess cake',
#   'Comment_author': '@priyaguru2502',
#   'Comment_published_date': '2024-02-10T13:38:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx8XcJfmuAQioewU8p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Try squareshape cake tin..',
#   'Comment_author': '@Anniepremlatha',
#   'Comment_published_date': '2024-02-10T13:35:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzT-n5IY_1V9UboA5d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '🎉🎉  Supper',
#   'Comment_author': '@haswathasri1967',
#   'Comment_published_date': '2024-02-10T13:32:20Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwq1zfX3a158dhB74t4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Very nice🎉🎉🎉🎉🎉🎉👌🏻👏👏',
#   'Comment_author': '@rrgroupsrr3819',
#   'Comment_published_date': '2024-02-10T13:30:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxHGptPW52a_ARpsSx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤🎉',
#   'Comment_author': '@kookieedits1502',
#   'Comment_published_date': '2024-02-10T13:28:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw1qa-JBc9bebco9Qp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super 2 comment',
#   'Comment_author': '@asin_edit_7464',
#   'Comment_published_date': '2024-02-10T13:28:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxlCWe54HyY60-dKih4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '😊Now a days ur doing cake designs very superb 😊.... ♟️This chess cake is very fantastic♟️...... ❤😢',
#   'Comment_author': '@jeevithabujji8360',
#   'Comment_published_date': '2024-02-10T13:28:16Z',
#   'Like_count': 123,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzWotBWexw1hlaePlx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow what a work....really super ma',
#   'Comment_author': '@jacisebas7381',
#   'Comment_published_date': '2024-02-10T13:23:47Z',
#   'Like_count': 7,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyOEXFr0jUGNzC6InF4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I&#39;m GM Judit polger while watching this chess cake I&#39;m  so  proud .',
#   'Comment_author': '@joshikajoshika5629',
#   'Comment_published_date': '2024-02-10T13:21:46Z',
#   'Like_count': 5,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugwdct9WVLp8tLtEmHZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sema creativity sis',
#   'Comment_author': '@sinegathirumal301',
#   'Comment_published_date': '2024-02-10T13:16:22Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxrwcgU-leBrOsT6E94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'First time pakura intha mari cake👌',
#   'Comment_author': '@priyangavinoth5643',
#   'Comment_published_date': '2024-02-10T13:14:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgymXP1X-HauBnTzRNd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Negga nalla ideavoda pandrega sis❤',
#   'Comment_author': '@rabiyaalmas5821',
#   'Comment_published_date': '2024-02-10T13:13:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzjVfGQiBvk8P1UY8N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka😊',
#   'Comment_author': '@DurgaDurga-kh6gj',
#   'Comment_published_date': '2024-02-10T13:11:39Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzFcw9iUYU4Ix1WANN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka cake varalavall',
#   'Comment_author': '@vasanthajvasantha841',
#   'Comment_published_date': '2024-02-10T13:08:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxlol4OIeih0tGKVGt4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 2 nd comment ❤ papa epdi irukanga akka i mean unga kutty thangam',
#   'Comment_author': '@SrinithiSandhiya',
#   'Comment_published_date': '2024-02-10T13:08:29Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxW7hhIdqY7Y2dmR9F4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka🎉',
#   'Comment_author': '@jeyasriSubasri-wy6te',
#   'Comment_published_date': '2024-02-10T13:08:01Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugz_GHCX65noXn-lo_N4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am also chess player♟️💗',
#   'Comment_author': '@Cutei_baby_Shanu',
#   'Comment_published_date': '2024-02-10T13:07:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxO24IxF4UbcM_I-8J4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤',
#   'Comment_author': '@user-hh1qg5pt1t',
#   'Comment_published_date': '2024-02-10T13:07:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznKMIrk77BQs-BjLx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Nice cake',
#   'Comment_author': '@m.k.arasan956',
#   'Comment_published_date': '2024-02-10T13:06:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxnYGrz8QT-iA7ZXux4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Really super akka.....your talented 👏',
#   'Comment_author': '@jesusrajij6290',
#   'Comment_published_date': '2024-02-10T13:01:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJqUVWLZZ5MLdcb5B4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super வாழ்த்துக்கள்',
#   'Comment_author': '@bpavithra736',
#   'Comment_published_date': '2024-02-10T12:58:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJJY6AHxSKPoNpk_14AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka one cake order in Salem please. <br>Akka ok va',
#   'Comment_author': '@pro-uzumaki',
#   'Comment_published_date': '2024-02-10T12:56:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqWVxHWIFjtL5IKB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka cake 🎉',
#   'Comment_author': '@vijayenradhakrishnan6415',
#   'Comment_published_date': '2024-02-10T12:52:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzr1W63E2ov2b0Kx1p4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super  akka I love chess',
#   'Comment_author': '@sadhasivamravathisadhasiva5031',
#   'Comment_published_date': '2024-02-10T12:51:38Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwfP7IwR5lrtFO99JN4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super aa irukku akka 😘 3 comment',
#   'Comment_author': '@bhavaniharini4248',
#   'Comment_published_date': '2024-02-10T12:50:19Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxjxvugwni-yrY1LNR4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka first comment',
#   'Comment_author': '@user-tg8ir9pe5r',
#   'Comment_published_date': '2024-02-10T12:50:17Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw6Xw967e5kYJlr3jd4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'சூப்பர்❤❤',
#   'Comment_author': '@user-sl6ms5to5b',
#   'Comment_published_date': '2024-02-10T12:47:09Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzIOHOIpqI9UhwUkL54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sis romba unique ah pandringa❤️...super ah iruku❤️❤️🎉<br>All the best❤️',
#   'Comment_author': '@umaghayathrii3276',
#   'Comment_published_date': '2024-02-10T12:46:51Z',
#   'Like_count': 10,
#   'Reply_count': 0},
#  {'Comment_id': 'UgztGaw6LnJG0iByDv54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka na unga thivera fan pappaoda smilekku na adimai',
#   'Comment_author': '@NarutoTamil-rw8dl',
#   'Comment_published_date': '2024-02-10T12:44:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzVXxLsBx7V9vGpWSV4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Awesome',
#   'Comment_author': '@AkilandeswariRajesh',
#   'Comment_published_date': '2024-02-10T12:44:07Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxbWd5vkRy0hDP_Qv94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka super akka',
#   'Comment_author': '@sfsameeh0449',
#   'Comment_published_date': '2024-02-10T12:43:56Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwU7mTTIRin8IBZ1YB4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I am a chess player but I am a small cute Girl I am studying 4th std A section',
#   'Comment_author': '@Jaigowshith2007',
#   'Comment_published_date': '2024-02-10T12:43:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyUWFprNXkIvmhV4_d4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Unic super ❤❤❤❤❤❤',
#   'Comment_author': '@user-sy2sp1kw5w',
#   'Comment_published_date': '2024-02-10T12:43:02Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzd9YLAk_KsuKZnk-R4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka 1st comment pin me please 😢',
#   'Comment_author': '@elongorevathi135',
#   'Comment_published_date': '2024-02-10T12:42:16Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxSH81hC7rn0P_zQwx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'யாருக்கெல்லாம் ருத்திகா பாபாவை புடிக்கும் LIKE IT❤️',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:41:00Z',
#   'Like_count': 56,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyv-GXsBWD4HRegjAx4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Wow❤',
#   'Comment_author': '@vinnolivinnoli8300',
#   'Comment_published_date': '2024-02-10T12:40:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzClpxnTuayck8uck94AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤❤',
#   'Comment_author': '@GamingItzMe',
#   'Comment_published_date': '2024-02-10T12:38:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx6NkOz2XNy3Gn7X-54AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super❤❤❤',
#   'Comment_author': '@padmavathi1186',
#   'Comment_published_date': '2024-02-10T12:37:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwW4fusN1shXkAlBwp4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Hi akka ❤❤',
#   'Comment_author': '@sathyapriyav9599',
#   'Comment_published_date': '2024-02-10T12:36:50Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxYzIBHOnVcd9e_KJZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Salem only <br>Whatsapp:9788582192<br>Insta id :tharu_passion',
#   'Comment_author': '@Tharus_passion09',
#   'Comment_published_date': '2024-02-10T12:35:13Z',
#   'Like_count': 19,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxfZ9Zo-EYrcL0ZgPZ4AaABAg',
#   'Video_id': 'OMEAehSu3-g',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Supper 🎉',
# ...
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '😁',
#   'Comment_author': '@sarunsarujan1734',
#   'Comment_published_date': '2023-11-22T12:30:25Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw7J8qapu4FrNOJk954AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super sister 🎉❤🎉',
#   'Comment_author': '@tamilselvan-gf9wt',
#   'Comment_published_date': '2023-11-21T08:32:24Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzpRlQGY4Vi5SYTuup4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Dream cake how much akka',
#   'Comment_author': '@Timepassmedia751',
#   'Comment_published_date': '2023-11-17T16:29:28Z',
#   'Like_count': 4,
#   'Reply_count': 0},
#  {'Comment_id': 'UgygDF3Xw05GoGZFfVR4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Please use gloves for hands verun Kaiya use pannatha ma',
#   'Comment_author': '@AttharahLydia',
#   'Comment_published_date': '2023-11-14T04:06:57Z',
#   'Like_count': 3,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwRWTJ_iozkDT9slat4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sisiter nenga chennaiku la delivery pannuvingq la 😊',
#   'Comment_author': '@karthikakarthika3922',
#   'Comment_published_date': '2023-11-11T09:36:45Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJAfKbG-TsGzMl5QB4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka unga anna wife ah ka   unga papavaiym rithika um pudikkum ❤❤❤',
#   'Comment_author': '@unismk2132',
#   'Comment_published_date': '2023-11-07T09:15:02Z',
#   'Like_count': 3,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyxe2qoGnIbUVM3QEF4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Neenga entha ooru enga cake baking padichinga',
#   'Comment_author': '@sivania3161',
#   'Comment_published_date': '2023-11-04T09:50:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxE0P4pSjXUBYLxUS94AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Brownie how much sister',
#   'Comment_author': '@noortheennoortheen2437',
#   'Comment_published_date': '2023-10-29T13:28:34Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyFlBclF5sH5ilQscR4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Theryum akka❤neenga kamichutingaa 😂❤',
#   'Comment_author': '@AmalarajaramAmalarajaram',
#   'Comment_published_date': '2023-10-27T15:56:32Z',
#   'Like_count': 7,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxQg9dDYvDm4GJQTyl4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Bank class online eruka soluga',
#   'Comment_author': '@vidhushreefamily1174',
#   'Comment_published_date': '2023-10-27T08:13:04Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzYxbRRHnLOFvgMyqx4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'akka na sivagangkai  mavattam sis enakku Delivery pannuvingkala',
#   'Comment_author': '@sayedmajitha2527',
#   'Comment_published_date': '2023-10-25T14:35:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxAWpaU_zvbSaLUxol4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'கேக் எப்படி செய்றதுன்னு சொல்லி வீடியோ போடுங்க அக்கா',
#   'Comment_author': '@priyakiran3939',
#   'Comment_published_date': '2023-10-11T03:06:06Z',
#   'Like_count': 26,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx8I0mVmcQ_tRhhZ6B4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤',
#   'Comment_author': '@bharathic2712',
#   'Comment_published_date': '2023-10-09T10:25:55Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2-FBH0dpIh8jlXEN4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'ருத்திகா அத்தை தானே',
#   'Comment_author': '@SaranSaran-wt3dv',
#   'Comment_published_date': '2023-08-19T03:57:42Z',
#   'Like_count': 93,
#   'Reply_count': 1},
#  {'Comment_id': 'UgyAqkjRtjX6JR8xyY54AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤',
#   'Comment_author': '@jayaramanjaya911',
#   'Comment_published_date': '2023-08-17T17:00:58Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw-DWspMWSr2Ux99Ax4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'வசு',
#   'Comment_author': '@user-fy8vw1mw3v',
#   'Comment_published_date': '2023-08-17T10:55:29Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzLkHE0KpwTaSVQEBl4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super sisy❤',
#   'Comment_author': '@tamilboynilaxshan8587',
#   'Comment_published_date': '2023-08-17T05:04:14Z',
#   'Like_count': 9,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyzVZKrTgBlYjbq-2N4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Watch yen right handla katirukinga? Left tha katanumnu yarum solikudukalaya?',
#   'Comment_author': '@andril0019',
#   'Comment_published_date': '2023-08-17T03:39:11Z',
#   'Like_count': 8,
#   'Reply_count': 5},
#  {'Comment_id': 'UgxXTqfNwadaYnGRRYp4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sweet voice akka',
#   'Comment_author': '@ChitraChitra-jg3ll',
#   'Comment_published_date': '2024-01-26T15:53:38Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy9pT_pdvhUTR_ePVx4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'White chocolate yenga vanguvinga',
#   'Comment_author': '@awesomenp5546',
#   'Comment_published_date': '2024-01-07T12:26:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwhih7PlNc_hSv-qQZ4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka ungala ennaku romba pidichi eruku akka',
#   'Comment_author': '@dhivya8933',
#   'Comment_published_date': '2023-11-29T15:12:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxLcpYrwMnO0MWEz-F4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '😁',
#   'Comment_author': '@sarunsarujan1734',
#   'Comment_published_date': '2023-11-22T12:30:25Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw7J8qapu4FrNOJk954AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super sister 🎉❤🎉',
#   'Comment_author': '@tamilselvan-gf9wt',
#   'Comment_published_date': '2023-11-21T08:32:24Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzpRlQGY4Vi5SYTuup4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Dream cake how much akka',
#   'Comment_author': '@Timepassmedia751',
#   'Comment_published_date': '2023-11-17T16:29:28Z',
#   'Like_count': 4,
#   'Reply_count': 0},
#  {'Comment_id': 'UgygDF3Xw05GoGZFfVR4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Please use gloves for hands verun Kaiya use pannatha ma',
#   'Comment_author': '@AttharahLydia',
#   'Comment_published_date': '2023-11-14T04:06:57Z',
#   'Like_count': 3,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwRWTJ_iozkDT9slat4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Sisiter nenga chennaiku la delivery pannuvingq la 😊',
#   'Comment_author': '@karthikakarthika3922',
#   'Comment_published_date': '2023-11-11T09:36:45Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxJAfKbG-TsGzMl5QB4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Akka unga anna wife ah ka   unga papavaiym rithika um pudikkum ❤❤❤',
#   'Comment_author': '@unismk2132',
#   'Comment_published_date': '2023-11-07T09:15:02Z',
#   'Like_count': 3,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyxe2qoGnIbUVM3QEF4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Neenga entha ooru enga cake baking padichinga',
#   'Comment_author': '@sivania3161',
#   'Comment_published_date': '2023-11-04T09:50:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxE0P4pSjXUBYLxUS94AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Brownie how much sister',
#   'Comment_author': '@noortheennoortheen2437',
#   'Comment_published_date': '2023-10-29T13:28:34Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyFlBclF5sH5ilQscR4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Theryum akka❤neenga kamichutingaa 😂❤',
#   'Comment_author': '@AmalarajaramAmalarajaram',
#   'Comment_published_date': '2023-10-27T15:56:32Z',
#   'Like_count': 7,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxQg9dDYvDm4GJQTyl4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Bank class online eruka soluga',
#   'Comment_author': '@vidhushreefamily1174',
#   'Comment_published_date': '2023-10-27T08:13:04Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzYxbRRHnLOFvgMyqx4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'akka na sivagangkai  mavattam sis enakku Delivery pannuvingkala',
#   'Comment_author': '@sayedmajitha2527',
#   'Comment_published_date': '2023-10-25T14:35:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxAWpaU_zvbSaLUxol4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'கேக் எப்படி செய்றதுன்னு சொல்லி வீடியோ போடுங்க அக்கா',
#   'Comment_author': '@priyakiran3939',
#   'Comment_published_date': '2023-10-11T03:06:06Z',
#   'Like_count': 26,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx8I0mVmcQ_tRhhZ6B4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka❤',
#   'Comment_author': '@bharathic2712',
#   'Comment_published_date': '2023-10-09T10:25:55Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2-FBH0dpIh8jlXEN4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'ருத்திகா அத்தை தானே',
#   'Comment_author': '@SaranSaran-wt3dv',
#   'Comment_published_date': '2023-08-19T03:57:42Z',
#   'Like_count': 93,
#   'Reply_count': 1},
#  {'Comment_id': 'UgyAqkjRtjX6JR8xyY54AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': '❤',
#   'Comment_author': '@jayaramanjaya911',
#   'Comment_published_date': '2023-08-17T17:00:58Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw-DWspMWSr2Ux99Ax4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'வசு',
#   'Comment_author': '@user-fy8vw1mw3v',
#   'Comment_published_date': '2023-08-17T10:55:29Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzLkHE0KpwTaSVQEBl4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super sisy❤',
#   'Comment_author': '@tamilboynilaxshan8587',
#   'Comment_published_date': '2023-08-17T05:04:14Z',
#   'Like_count': 9,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyzVZKrTgBlYjbq-2N4AaABAg',
#   'Video_id': 'Pe11ygOtskM',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Watch yen right handla katirukinga? Left tha katanumnu yarum solikudukalaya?',
#   'Comment_author': '@andril0019',
#   'Comment_published_date': '2023-08-17T03:39:11Z',
#   'Like_count': 8,
#   'Reply_count': 5},
#  {'Comment_id': 'UgyM1Qw2b_6JlOTzA5d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Vijay anna pls arashiyal vendam ungalukku 😢😢😢😢',
#   'Comment_author': '@yuvaSamuel1904',
#   'Comment_published_date': '2023-06-20T10:59:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxEFZnJsiFqN0nEtMp4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka ❤❤',
#   'Comment_author': '@naleemnaleem1030',
#   'Comment_published_date': '2023-06-20T10:52:43Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzm51cZrGjg24Pd-0d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I live this...😍😍😍',
#   'Comment_author': '@bhuvaneshwarip8807',
#   'Comment_published_date': '2023-06-19T13:48:55Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM1Qw2b_6JlOTzA5d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Vijay anna pls arashiyal vendam ungalukku 😢😢😢😢',
#   'Comment_author': '@yuvaSamuel1904',
#   'Comment_published_date': '2023-06-20T10:59:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxEFZnJsiFqN0nEtMp4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka ❤❤',
#   'Comment_author': '@naleemnaleem1030',
#   'Comment_published_date': '2023-06-20T10:52:43Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzm51cZrGjg24Pd-0d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I live this...😍😍😍',
#   'Comment_author': '@bhuvaneshwarip8807',
#   'Comment_published_date': '2023-06-19T13:48:55Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM1Qw2b_6JlOTzA5d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Vijay anna pls arashiyal vendam ungalukku 😢😢😢😢',
#   'Comment_author': '@yuvaSamuel1904',
#   'Comment_published_date': '2023-06-20T10:59:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxEFZnJsiFqN0nEtMp4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka ❤❤',
#   'Comment_author': '@naleemnaleem1030',
#   'Comment_published_date': '2023-06-20T10:52:43Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzm51cZrGjg24Pd-0d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I live this...😍😍😍',
#   'Comment_author': '@bhuvaneshwarip8807',
#   'Comment_published_date': '2023-06-19T13:48:55Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM1Qw2b_6JlOTzA5d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Vijay anna pls arashiyal vendam ungalukku 😢😢😢😢',
#   'Comment_author': '@yuvaSamuel1904',
#   'Comment_published_date': '2023-06-20T10:59:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxEFZnJsiFqN0nEtMp4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka ❤❤',
#   'Comment_author': '@naleemnaleem1030',
#   'Comment_published_date': '2023-06-20T10:52:43Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzm51cZrGjg24Pd-0d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I live this...😍😍😍',
#   'Comment_author': '@bhuvaneshwarip8807',
#   'Comment_published_date': '2023-06-19T13:48:55Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM1Qw2b_6JlOTzA5d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Vijay anna pls arashiyal vendam ungalukku 😢😢😢😢',
#   'Comment_author': '@yuvaSamuel1904',
#   'Comment_published_date': '2023-06-20T10:59:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxEFZnJsiFqN0nEtMp4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'Super akka ❤❤',
#   'Comment_author': '@naleemnaleem1030',
#   'Comment_published_date': '2023-06-20T10:52:43Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzm51cZrGjg24Pd-0d4AaABAg',
#   'Video_id': 'C37h5jgau6M',
#   'channel_name': "Tharu's_passion",
#   'Comment_text': 'I live this...😍😍😍',
#   'Comment_author': '@bhuvaneshwarip8807',
#   'Comment_published_date': '2023-06-19T13:48:55Z',
#   'Like_count': 0,
#   'Reply_count': 0}]

# %%
information3 = db.comment_db
information3.insert_many(comm_det)
# Out:
# InsertManyResult([ObjectId('65c907d68f8b8931c67413f8'), ObjectId('65c907d68f8b8931c67413f9'), ObjectId('65c907d68f8b8931c67413fa'), ObjectId('65c907d68f8b8931c67413fb'), ObjectId('65c907d68f8b8931c67413fc'), ObjectId('65c907d68f8b8931c67413fd'), ObjectId('65c907d68f8b8931c67413fe'), ObjectId('65c907d68f8b8931c67413ff'), ObjectId('65c907d68f8b8931c6741400'), ObjectId('65c907d68f8b8931c6741401'), ObjectId('65c907d68f8b8931c6741402'), ObjectId('65c907d68f8b8931c6741403'), ObjectId('65c907d68f8b8931c6741404'), ObjectId('65c907d68f8b8931c6741405'), ObjectId('65c907d68f8b8931c6741406'), ObjectId('65c907d68f8b8931c6741407'), ObjectId('65c907d68f8b8931c6741408'), ObjectId('65c907d68f8b8931c6741409'), ObjectId('65c907d68f8b8931c674140a'), ObjectId('65c907d68f8b8931c674140b'), ObjectId('65c907d68f8b8931c674140c'), ObjectId('65c907d68f8b8931c674140d'), ObjectId('65c907d68f8b8931c674140e'), ObjectId('65c907d68f8b8931c674140f'), ObjectId('65c907d68f8b8931c6741410'), ObjectId('65c907d68f8b8931c6741411'), ObjectId('65c907d68f8b8931c6741412'), ObjectId('65c907d68f8b8931c6741413'), ObjectId('65c907d68f8b8931c6741414'), ObjectId('65c907d68f8b8931c6741415'), ObjectId('65c907d68f8b8931c6741416'), ObjectId('65c907d68f8b8931c6741417'), ObjectId('65c907d68f8b8931c6741418'), ObjectId('65c907d68f8b8931c6741419'), ObjectId('65c907d68f8b8931c674141a'), ObjectId('65c907d68f8b8931c674141b'), ObjectId('65c907d68f8b8931c674141c'), ObjectId('65c907d68f8b8931c674141d'), ObjectId('65c907d68f8b8931c674141e'), ObjectId('65c907d68f8b8931c674141f'), ObjectId('65c907d68f8b8931c6741420'), ObjectId('65c907d68f8b8931c6741421'), ObjectId('65c907d68f8b8931c6741422'), ObjectId('65c907d68f8b8931c6741423'), ObjectId('65c907d68f8b8931c6741424'), ObjectId('65c907d68f8b8931c6741425'), ObjectId('65c907d68f8b8931c6741426'), ObjectId('65c907d68f8b8931c6741427'), ObjectId('65c907d68f8b8931c6741428'), ObjectId('65c907d68f8b8931c6741429'), ObjectId('65c907d68f8b8931c674142a'), ObjectId('65c907d68f8b8931c674142b'), ObjectId('65c907d68f8b8931c674142c'), ObjectId('65c907d68f8b8931c674142d'), ObjectId('65c907d68f8b8931c674142e'), ObjectId('65c907d68f8b8931c674142f'), ObjectId('65c907d68f8b8931c6741430'), ObjectId('65c907d68f8b8931c6741431'), ObjectId('65c907d68f8b8931c6741432'), ObjectId('65c907d68f8b8931c6741433'), ObjectId('65c907d68f8b8931c6741434'), ObjectId('65c907d68f8b8931c6741435'), ObjectId('65c907d68f8b8931c6741436'), ObjectId('65c907d68f8b8931c6741437'), ObjectId('65c907d68f8b8931c6741438'), ObjectId('65c907d68f8b8931c6741439'), ObjectId('65c907d68f8b8931c674143a'), ObjectId('65c907d68f8b8931c674143b'), ObjectId('65c907d68f8b8931c674143c'), ObjectId('65c907d68f8b8931c674143d'), ObjectId('65c907d68f8b8931c674143e'), ObjectId('65c907d68f8b8931c674143f'), ObjectId('65c907d68f8b8931c6741440'), ObjectId('65c907d68f8b8931c6741441'), ObjectId('65c907d68f8b8931c6741442'), ObjectId('65c907d68f8b8931c6741443'), ObjectId('65c907d68f8b8931c6741444'), ObjectId('65c907d68f8b8931c6741445'), ObjectId('65c907d68f8b8931c6741446'), ObjectId('65c907d68f8b8931c6741447'), ObjectId('65c907d68f8b8931c6741448'), ObjectId('65c907d68f8b8931c6741449'), ObjectId('65c907d68f8b8931c674144a'), ObjectId('65c907d68f8b8931c674144b'), ObjectId('65c907d68f8b8931c674144c'), ObjectId('65c907d68f8b8931c674144d'), ObjectId('65c907d68f8b8931c674144e'), ObjectId('65c907d68f8b8931c674144f'), ObjectId('65c907d68f8b8931c6741450'), ObjectId('65c907d68f8b8931c6741451'), ObjectId('65c907d68f8b8931c6741452'), ObjectId('65c907d68f8b8931c6741453'), ObjectId('65c907d68f8b8931c6741454'), ObjectId('65c907d68f8b8931c6741455'), ObjectId('65c907d68f8b8931c6741456'), ObjectId('65c907d68f8b8931c6741457'), ObjectId('65c907d68f8b8931c6741458'), ObjectId('65c907d68f8b8931c6741459'), ObjectId('65c907d68f8b8931c674145a'), ObjectId('65c907d68f8b8931c674145b'), ObjectId('65c907d68f8b8931c674145c'), ObjectId('65c907d68f8b8931c674145d'), ObjectId('65c907d68f8b8931c674145e'), ObjectId('65c907d68f8b8931c674145f'), ObjectId('65c907d68f8b8931c674 ...

# %%
import pymysql as sql
import pymongo

# %%
mydb = sql.connect(host="localhost",port=3306,
                        user="root",
                        password="admin@123")
mycursor = mydb.cursor()

# %%
client = pymongo.MongoClient('mongodb://localhost:27017')    
db = client['youtube_details']

# %%
data = []
info1 = db.channel_details
for i in info1.find({},{'channel_name':1,'_id':0}):
    data.append(i)
data
# Out:
# [{'channel_name': 'Riyabi Vlog'},
#  {'channel_name': "Tharu's_passion"},
#  {'channel_name': 'Kavitha1285'},
#  {'channel_name': 'Pink Pearls Chennai'},
#  {'channel_name': 'Ram Sivaritha Shorts'},
#  {'channel_name': 'Danam_mua'},
#  {'channel_name': 'Trending JK'},
#  {'channel_name': 'Cooktastycook'},
#  {'channel_name': 'Maya  lifestyles '}]

# %%
[d['channel_name'] for d in data]
# Out:
# ['Riyabi Vlog',
#  "Tharu's_passion",
#  'Kavitha1285',
#  'Pink Pearls Chennai',
#  'Ram Sivaritha Shorts',
#  'Danam_mua',
#  'Trending JK',
#  'Cooktastycook',
#  'Maya  lifestyles ']

# %%
mycursor.execute("create database titanic")
# Out:
# 1

# %%
mydb = sql.connect(host="localhost",port=3306,
                        user="root",
                        password="admin@123",database="youtube")
mycur = mydb.cursor()

# %%
collections = db.channel_details
collections
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'youtube_details'), 'channel_details')

# %%
data1 = []
for i in collections.find({},{'_id':0}):
    data1.append(i)
data1
# Out:
# [{'channel_name': 'Riyabi Vlog',
#   'channel_id': 'UCyQTK6QSrJn-o_4dV0joJFA',
#   'playlist_id': 'UUyQTK6QSrJn-o_4dV0joJFA',
#   'subscription_count': '1160',
#   'channel_viewcount': '7797',
#   'channel_description': 'Welcome to our family🙏',
#   'total_videos_count': '28'},
#  {'channel_name': "Tharu's_passion",
#   'channel_id': 'UCvWBS0Vds2x3ehaw7DdEg3w',
#   'playlist_id': 'UUvWBS0Vds2x3ehaw7DdEg3w',
#   'subscription_count': '628000',
#   'channel_viewcount': '247019895',
#   'channel_description': 'Hii guys...\nWelcome to our channel guys\nI made all types of cakes in day by day\n\nInstagram id:https://instagram.com/tharu_passion?utm_source=qr&igshid=MzNlNGNkZWQ4Mg%3D%3D',
#   'total_videos_count': '228'},
#  {'channel_name': 'Kavitha1285',
#   'channel_id': 'UCJvHL0udkAy51nL1Po_ST6g',
#   'playlist_id': 'UUJvHL0udkAy51nL1Po_ST6g',
#   'subscription_count': '519',
#   'channel_viewcount': '176278',
#   'channel_description': 'Kavitha1285  lam Kavitha  in Chennai kavitha vlogs samayal recipe village.vlog shipping video  family vlog please subscribe thank you very much for me kavitha🙏🙏\n\n\n',
#   'total_videos_count': '107'},
#  {'channel_name': 'Pink Pearls Chennai',
#   'channel_id': 'UCCtOiSS9xSyj7mHA-vVK_nQ',
#   'playlist_id': 'UUCtOiSS9xSyj7mHA-vVK_nQ',
#   'subscription_count': '403',
#   'channel_viewcount': '61639',
#   'channel_description': 'We deal with women clothing and jewelry.\nOwn brand Kurtis\nUndertake customise orders for kurtis, long gowns, feeding kurtis, nighties, kaftans, etc.  \n\nVisit our social websites to place your order\n\nwww.facebook.com/pinkpearlschennai\n\nwww.facebook.com/pinkpearlsclothing\n\nwww.instagram.com/pinkpearlschennai\n\nwhats app 9884329333',
#   'total_videos_count': '208'},
#  {'channel_name': 'Ram Sivaritha Shorts',
#   'channel_id': 'UCk2EPDOXZDNMQSduDc7lyZA',
#   'playlist_id': 'UUk2EPDOXZDNMQSduDc7lyZA',
#   'subscription_count': '86800',
#   'channel_viewcount': '38375315',
#   'channel_description': 'Hi Everyone,Ram Sivaritha shorts" is an exciting YouTube channel that combines the joys of food exploration and adventure. \n\nHosted by Ram Sivaritha, this channel offers a diverse range of content, from savoring delicious dishes to experiencing thrilling travel adventures and exciting activities. \n\nViewers are encouraged to engage with the community by liking, commenting, and subscribing. \n\nJoin "Ram Sivaritha Shorts" for a \nvirtual journey filled with mouthwatering food discoveries and exhilarating escapades, where every adventure becomes a story worth sharing.\n',
#   'total_videos_count': '117'},
#  {'channel_name': 'Danam_mua',
#   'channel_id': 'UCjfi44A_cuLnKJyi0UZ13EA',
#   'playlist_id': 'UUjfi44A_cuLnKJyi0UZ13EA',
#   'subscription_count': '12400',
#   'channel_viewcount': '8806505',
#   'channel_description': 'A YouTube danam_mua hair and makeup channel is a platform that provides viewers with tutorials, tips, and advice on various beauty and grooming topics. From hairstyles to makeup looks, skincare to hair care, this channel covers a wide range of topics related to beauty.\n\nThe channel typically features videos hosted by Dhanalakshmi shares her knowledge and expertise on various beauty-related subjects. These videos may include step-by-step tutorials on creating specific looks or tips on how to use certain products.\n\nIn addition to tutorials, a hair and makeup channel may also feature product reviews, recommendations, and hauls. The host may share their thoughts and opinions on the latest beauty products and trends, and provide viewers with an inside look at their personal beauty routines.\n\nOverall, a hair and makeup channel is a great resource for anyone looking to improve their beauty and grooming skills, stay up-to-date on the latest trends, and get inspired to try new looks. Thanks \n',
#   'total_videos_count': '246'},
#  {'channel_name': 'Trending JK',
#   'channel_id': 'UCQEnA_w-2kHSte-tl8TZDBw',
#   'playlist_id': 'UUQEnA_w-2kHSte-tl8TZDBw',
#   'subscription_count': '12700',
#   'channel_viewcount': '8486243',
#   'channel_description': 'All are Join Give Me Your Love & Support \n \nJoin Jk Family\n.\n.\nMy Instagram\nhttps://www.instagram.com/i_am_jk_u_m_a_r/\n\n1k      Reached - 23/04/2023   8.15 am\n5k      Reached - 20/01/2024   11 am\n10k    Reached - 22/01/2024   6.50 pm',
#   'total_videos_count': '258'},
#  {'channel_name': 'Cooktastycook',
#   'channel_id': 'UC8h_8XZB2kALeib3Nft9NhQ',
#   'playlist_id': 'UU8h_8XZB2kALeib3Nft9NhQ',
#   'subscription_count': '700',
#   'channel_viewcount': '257691',
#   'channel_description': '👋Hi friends...🙏Welcome to my channel Cooktastycook...I am interested in cooking varieties of recipes..just I wanted to share recipes that I know....and I  am also interested in roof gardening and home remedies for hair,skin and some internal treatments....also natural antibiotics\n ..🙏.pls subscribe and support my channel',
#   'total_videos_count': '210'},
#  {'channel_name': 'Maya  lifestyles ',
#   'channel_id': 'UCjVkKjfsZaJX5cbhvjtcyaw',
#   'playlist_id': 'UUjVkKjfsZaJX5cbhvjtcyaw',
#   'subscription_count': '228',
#   'channel_viewcount': '59238',
#   'channel_description': "Hi guys ........I'm  megakrish we make youtube  video  related to (lifestyle  fashion Haul skincare daily vlogs food Vlog   )...... Because  I do want to ( 9 to 5 ) and this Alone makes  me Happy guys .......And come &join with me on this beautiful  journey  guys ....... Loads  of love ",
#   'total_videos_count': '121'}]

# %%
sample = []
for i in range(0,len(data1)):
    sample.append(data1[i].values())
sample
# Out:
# [dict_values(['Riyabi Vlog', 'UCyQTK6QSrJn-o_4dV0joJFA', 'UUyQTK6QSrJn-o_4dV0joJFA', '1160', '7797', 'Welcome to our family🙏', '28']),
#  dict_values(["Tharu's_passion", 'UCvWBS0Vds2x3ehaw7DdEg3w', 'UUvWBS0Vds2x3ehaw7DdEg3w', '628000', '247019895', 'Hii guys...\nWelcome to our channel guys\nI made all types of cakes in day by day\n\nInstagram id:https://instagram.com/tharu_passion?utm_source=qr&igshid=MzNlNGNkZWQ4Mg%3D%3D', '228']),
#  dict_values(['Kavitha1285', 'UCJvHL0udkAy51nL1Po_ST6g', 'UUJvHL0udkAy51nL1Po_ST6g', '519', '176278', 'Kavitha1285  lam Kavitha  in Chennai kavitha vlogs samayal recipe village.vlog shipping video  family vlog please subscribe thank you very much for me kavitha🙏🙏\n\n\n', '107']),
#  dict_values(['Pink Pearls Chennai', 'UCCtOiSS9xSyj7mHA-vVK_nQ', 'UUCtOiSS9xSyj7mHA-vVK_nQ', '403', '61639', 'We deal with women clothing and jewelry.\nOwn brand Kurtis\nUndertake customise orders for kurtis, long gowns, feeding kurtis, nighties, kaftans, etc.  \n\nVisit our social websites to place your order\n\nwww.facebook.com/pinkpearlschennai\n\nwww.facebook.com/pinkpearlsclothing\n\nwww.instagram.com/pinkpearlschennai\n\nwhats app 9884329333', '208']),
#  dict_values(['Ram Sivaritha Shorts', 'UCk2EPDOXZDNMQSduDc7lyZA', 'UUk2EPDOXZDNMQSduDc7lyZA', '86800', '38375315', 'Hi Everyone,Ram Sivaritha shorts" is an exciting YouTube channel that combines the joys of food exploration and adventure. \n\nHosted by Ram Sivaritha, this channel offers a diverse range of content, from savoring delicious dishes to experiencing thrilling travel adventures and exciting activities. \n\nViewers are encouraged to engage with the community by liking, commenting, and subscribing. \n\nJoin "Ram Sivaritha Shorts" for a \nvirtual journey filled with mouthwatering food discoveries and exhilarating escapades, where every adventure becomes a story worth sharing.\n', '117']),
#  dict_values(['Danam_mua', 'UCjfi44A_cuLnKJyi0UZ13EA', 'UUjfi44A_cuLnKJyi0UZ13EA', '12400', '8806505', 'A YouTube danam_mua hair and makeup channel is a platform that provides viewers with tutorials, tips, and advice on various beauty and grooming topics. From hairstyles to makeup looks, skincare to hair care, this channel covers a wide range of topics related to beauty.\n\nThe channel typically features videos hosted by Dhanalakshmi shares her knowledge and expertise on various beauty-related subjects. These videos may include step-by-step tutorials on creating specific looks or tips on how to use certain products.\n\nIn addition to tutorials, a hair and makeup channel may also feature product reviews, recommendations, and hauls. The host may share their thoughts and opinions on the latest beauty products and trends, and provide viewers with an inside look at their personal beauty routines.\n\nOverall, a hair and makeup channel is a great resource for anyone looking to improve their beauty and grooming skills, stay up-to-date on the latest trends, and get inspired to try new looks. Thanks \n', '246']),
#  dict_values(['Trending JK', 'UCQEnA_w-2kHSte-tl8TZDBw', 'UUQEnA_w-2kHSte-tl8TZDBw', '12700', '8486243', 'All are Join Give Me Your Love & Support \n \nJoin Jk Family\n.\n.\nMy Instagram\nhttps://www.instagram.com/i_am_jk_u_m_a_r/\n\n1k      Reached - 23/04/2023   8.15 am\n5k      Reached - 20/01/2024   11 am\n10k    Reached - 22/01/2024   6.50 pm', '258']),
#  dict_values(['Cooktastycook', 'UC8h_8XZB2kALeib3Nft9NhQ', 'UU8h_8XZB2kALeib3Nft9NhQ', '700', '257691', '👋Hi friends...🙏Welcome to my channel Cooktastycook...I am interested in cooking varieties of recipes..just I wanted to share recipes that I know....and I  am also interested in roof gardening and home remedies for hair,skin and some internal treatments....also natural antibiotics\n ..🙏.pls subscribe and support my channel', '210']),
#  dict_values(['Maya  lifestyles ', 'UCjVkKjfsZaJX5cbhvjtcyaw', 'UUjVkKjfsZaJX5cbhvjtcyaw', '228', '59238', "Hi guys ........I'm  megakrish we make youtube  video  related to (lifestyle  fashion Haul skincare daily vlogs food Vlog   )...... Because  I do want to ( 9 to 5 ) and this Alone makes  me Happy guys .......And come &join with me on this beautiful  journey  guys ....... Loads  of love ", '121'])]

# %%
mycur.execute("create table channel_details(channel_name VARCHAR(255),channel_id VARCHAR(255),playlist_id VARCHAR(255),subs_count INT,view_count INT,video_count INT,channel_description VARCHAR(255))")
# Out:
# 0

# %%
mycur.execute("create table video_details(video_id VARCHAR(255),video_name VARCHAR(255),video_description TEXT,tags VARCHAR(255),published_date DATETIME,thumbnail VARCHAR(255),caption_status VARCHAR(255),duration VARCHAR(255),view_count INT,like_count INT,favourite_count INT,comment_count INT)")
# Out:
# 0

# %%
mycur.execute("create table comment_details(comment_id VARCHAR(255),video_id VARCHAR(255),comment_text TEXT,comment_author VARCHAR(255),comment_published_date DATETIME,like_count INT,reply_count INT)")
# Out:
# 0

# %%
query = "INSERT INTO channel_details VALUES(%s,%s,%s,%s,%s,%s,%s)"
                
for i in collections.find({"Channel_name" : 'Riyabi Vlog'},{'_id':0}):
    mycur.execute(query,tuple(i.values()))
    mydb.commit()

# %%
mydb = sql.connect(host="localhost",port=3306,
                        user="root",
                        password="admin@123",database="youtube")
mycur = mydb.cursor()

# %%
collections = db.channel_db

# %%
data1 = []
for i in collections.find({},{'_id':0}):
    data1.append(i)
data1
# Out:
# [{'channel_name': 'Aji Arts',
#   'channel_id': 'UCiSW3QmVduLq9MaInNONgWg',
#   'playlist_id': 'UUiSW3QmVduLq9MaInNONgWg',
#   'subscription_count': '3450',
#   'channel_viewcount': '859639',
#   'channel_description': "Hi! Nanba, I'm Ajai Kumar. Welcome to my channel.\n\nI do..\n\n1. Portraits\n2. Leaf art\n3. Caricature \n4. Book folding art\n5. Stencil art\n6. Spiral art\n\nCommission orders are taken. Message me on Instagram @ajipencilportrait \nDelivery available all over the country 🌎✈️🚚\nContact - +91 9551976271\n\nI need all you support and love ❤️ to our channel.\n\nDo Subscribe to our channel for more intersting Art videos.\n\nநன்றி!!\nகற்போம்! கற்பிப்போம்!!",
#   'total_videos_count': '119'},
#  {'channel_name': 'Lakshithakannan',
#   'channel_id': 'UCrPGjLet7wL5KBuuPl5FdAg',
#   'playlist_id': 'UUrPGjLet7wL5KBuuPl5FdAg',
#   'subscription_count': '1160',
#   'channel_viewcount': '490591',
#   'channel_description': 'hai friends welcome to lakshithakannan channel🥰❤️\nI will post useful videos for everyone ☺️\nmy channel is about nail art, ,art and craft, clay craft,easy drawings, unboxing, family vlogs, entertainment videos, painting ideas, funny videos,...etc...\nsubscribe for more useful videos 👍\nBe good,Do good ...\nsupport our channel friends\none subscriber=one step to motivation ',
#   'total_videos_count': '281'},
#  {'channel_name': "Farester Vlog's",
#   'channel_id': 'UCOvClRJZEHGTqrqzyboMF3g',
#   'playlist_id': 'UUOvClRJZEHGTqrqzyboMF3g',
#   'subscription_count': '56200',
#   'channel_viewcount': '21055457',
#   'channel_description': 'மருத்துவ மாணவன் ❤️\nAppetized Madurai Fellow Dissecting The Tasty Foods🍔🍸🍴 #மதுரைக்காரன்\nஆசைக்கு சாப்பிட்டாலும்,அளவாக சாப்பிடு.\n ',
#   'total_videos_count': '181'},
#  {'channel_name': 'Divyalakshmi',
#   'channel_id': 'UCMNr7kAMpaqgDHDLfHfTwDg',
#   'playlist_id': 'UUMNr7kAMpaqgDHDLfHfTwDg',
#   'subscription_count': '201000',
#   'channel_viewcount': '68151742',
#   'channel_description': 'This is my New Youtube Channel .Please Do Support Fam ❤🙏',
#   'total_videos_count': '155'},
#  {'channel_name': 'Dheekshutimes',
#   'channel_id': 'UCqFVPJDaz-ZTw0VbwBJhI2w',
#   'playlist_id': 'UUqFVPJDaz-ZTw0VbwBJhI2w',
#   'subscription_count': '181',
#   'channel_viewcount': '36223',
#   'channel_description': '',
#   'total_videos_count': '76'},
#  {'channel_name': 'Mr and Mrs YuviDhivi',
#   'channel_id': 'UCePYU1CX6WW5xskM4FDK_kw',
#   'playlist_id': 'UUePYU1CX6WW5xskM4FDK_kw',
#   'subscription_count': '1240',
#   'channel_viewcount': '225100',
#   'channel_description': 'Content creator | Blogger | traveller |\nDM/mail for promotion & collaboration\n',
#   'total_videos_count': '227'},
#  {'channel_name': 'Sk Fit Feed ',
#   'channel_id': 'UCBzQxo_xW0q4jbbQ5yVjYGA',
#   'playlist_id': 'UUBzQxo_xW0q4jbbQ5yVjYGA',
#   'subscription_count': '33',
#   'channel_viewcount': '9397',
#   'channel_description': 'Fitness trainer \n\n“Helping you build a strong foundation of health and fitness.” \n\n',
#   'total_videos_count': '15'},
#  {'channel_name': 'Zana samayal',
#   'channel_id': 'UC2oSoOQCxpP6W6ejWz1p6qA',
#   'playlist_id': 'UU2oSoOQCxpP6W6ejWz1p6qA',
#   'subscription_count': '345',
#   'channel_viewcount': '89190',
#   'channel_description': 'Hi, welcome to zana samayal. This channel is for cooking Tamil recipes and life style, and entertainment. Pls subscribe. \n',
#   'total_videos_count': '152'},
#  {'channel_name': 'Pink Pearls Chennai',
#   'channel_id': 'UCCtOiSS9xSyj7mHA-vVK_nQ',
#   'playlist_id': 'UUCtOiSS9xSyj7mHA-vVK_nQ',
#   'subscription_count': '403',
#   'channel_viewcount': '61660',
#   'channel_description': 'We deal with women clothing and jewelry.\nOwn brand Kurtis\nUndertake customise orders for kurtis, long gowns, feeding kurtis, nighties, kaftans, etc.  \n\nVisit our social websites to place your order\n\nwww.facebook.com/pinkpearlschennai\n\nwww.facebook.com/pinkpearlsclothing\n\nwww.instagram.com/pinkpearlschennai\n\nwhats app 9884329333',
#   'total_videos_count': '208'},
#  {'channel_name': "Tharu's_passion",
#   'channel_id': 'UCvWBS0Vds2x3ehaw7DdEg3w',
#   'playlist_id': 'UUvWBS0Vds2x3ehaw7DdEg3w',
#   'subscription_count': '632000',
#   'channel_viewcount': '248751930',
#   'channel_description': 'Hii guys...\nWelcome to our channel guys\nI made all types of cakes in day by day\n\nInstagram id:https://instagram.com/tharu_passion?utm_source=qr&igshid=MzNlNGNkZWQ4Mg%3D%3D',
#   'total_videos_count': '228'}]

# %%
collections1 = db.video_db
data1 = []
for i in collections1.find({},{'_id':0}):
    data1.append(i)
data1
# Out:
# [{'video_id': 'TAiXf744rFQ',
#   'video_name': 'Rahul M Leaf Art🍃 | Aji Arts #shorts',
#   'channel_name': 'Aji Arts',
#   'video_description': 'Hi Nanba,\n\nThese gifts are enough to impress your loved ones❤️\nMessage me on Instagram to know about the details 💬 @ajipencilportrait (Aji Arts) \n\nArt Products list:\n⭐️ Portraits\n⭐️ Leaf art\n⭐️ Caricature \n⭐️ Book folding art\n⭐️ Stencil art\n⭐️ Spiral art\n\n🔺Shipping available all over the country.\n🔺Delivery within 3-5  working days It’s depending on your location.\n🔺Fully hand made art products🍃\n\nFor more details : +91 9551976271\n\nPlease Subscribe for more videos👍🏻\n\nThanks for watching ❤️',
#   'published_at': '2024-02-10T11:51:38Z',
#   'thumbnail': 'https://i.ytimg.com/vi/TAiXf744rFQ/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT6S',
#   'view_count': '288',
#   'like_count': '12',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'TAiXf744rFQ',
#   'video_name': 'Rahul M Leaf Art🍃 | Aji Arts #shorts',
#   'channel_name': 'Aji Arts',
#   'video_description': 'Hi Nanba,\n\nThese gifts are enough to impress your loved ones❤️\nMessage me on Instagram to know about the details 💬 @ajipencilportrait (Aji Arts) \n\nArt Products list:\n⭐️ Portraits\n⭐️ Leaf art\n⭐️ Caricature \n⭐️ Book folding art\n⭐️ Stencil art\n⭐️ Spiral art\n\n🔺Shipping available all over the country.\n🔺Delivery within 3-5  working days It’s depending on your location.\n🔺Fully hand made art products🍃\n\nFor more details : +91 9551976271\n\nPlease Subscribe for more videos👍🏻\n\nThanks for watching ❤️',
#   'published_at': '2024-02-10T11:51:38Z',
#   'thumbnail': 'https://i.ytimg.com/vi/TAiXf744rFQ/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT6S',
#   'view_count': '288',
#   'like_count': '12',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'TAiXf744rFQ',
#   'video_name': 'Rahul M Leaf Art🍃 | Aji Arts #shorts',
#   'channel_name': 'Aji Arts',
#   'video_description': 'Hi Nanba,\n\nThese gifts are enough to impress your loved ones❤️\nMessage me on Instagram to know about the details 💬 @ajipencilportrait (Aji Arts) \n\nArt Products list:\n⭐️ Portraits\n⭐️ Leaf art\n⭐️ Caricature \n⭐️ Book folding art\n⭐️ Stencil art\n⭐️ Spiral art\n\n🔺Shipping available all over the country.\n🔺Delivery within 3-5  working days It’s depending on your location.\n🔺Fully hand made art products🍃\n\nFor more details : +91 9551976271\n\nPlease Subscribe for more videos👍🏻\n\nThanks for watching ❤️',
#   'published_at': '2024-02-10T11:51:38Z',
#   'thumbnail': 'https://i.ytimg.com/vi/TAiXf744rFQ/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT6S',
#   'view_count': '288',
#   'like_count': '12',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'Fpfx-LoADoI',
#   'video_name': 'sappadu comedy...fun..new.. food..tasty..veg',
#   'channel_name': 'Lakshithakannan',
#   'video_description': '',
#   'published_at': '2024-02-10T05:38:59Z',
#   'thumbnail': 'https://i.ytimg.com/vi/Fpfx-LoADoI/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT10S',
#   'view_count': '3555',
#   'like_count': '81',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'qIRiZBVZ1Jc',
#   'video_name': 'roatukadai style podi dosa|| dosa recipe.. food spicy 🔥',
#   'channel_name': 'Lakshithakannan',
#   'video_description': '',
#   'published_at': '2023-06-08T15:44:33Z',
#   'thumbnail': 'https://i.ytimg.com/vi/qIRiZBVZ1Jc/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT32S',
#   'view_count': '943',
#   'like_count': '27',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'IViub4pPi84',
#   'video_name': 'Madurai Famous Iyer Tiffin ❣️🔥#madurai #foodie',
#   'channel_name': "Farester Vlog's",
#   'video_description': '#madurai  #maduraifoods  #maduraifoodie #maduraifood #foodie #foodblogger #food  \n#tiffin  #tiffinrecipe  #tiffinbox #maduraitemples#idly #poori #idlydosa',
#   'published_at': '2024-02-11T15:08:51Z',
#   'thumbnail': 'https://i.ytimg.com/vi/IViub4pPi84/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT27S',
#   'view_count': '458',
#   'like_count': '218',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'o8fSEmtmrmY',
#   'video_name': 'SS Motors - Used Two Wheelers Branches: Saravanampatti, Thudiyalur, Sulur',
#   'channel_name': 'Divyalakshmi',
#   'video_description': '',
#   'published_at': '2024-02-10T13:33:11Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o8fSEmtmrmY/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT39S',
#   'view_count': '2782',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '27',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '27',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '27',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '27',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '30',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'o_f8j1WGBhE',
#   'video_name': 'Passion to learn.. #shorts #learning #scooty #naatunaatu #rrr',
#   'channel_name': 'Dheekshutimes',
#   'video_description': '',
#   'published_at': '2024-02-11T15:07:46Z',
#   'thumbnail': 'https://i.ytimg.com/vi/o_f8j1WGBhE/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT52S',
#   'view_count': '30',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'FlWAWSe0XyQ',
#   'video_name': 'irukka illaya challenge | challenge no.147 #shorts #challengevideo #trendingshorts #irukkaillaya #1m',
#   'channel_name': 'Mr and Mrs YuviDhivi',
#   'video_description': '',
#   'published_at': '2024-02-11T15:46:07Z',
#   'thumbnail': 'https://i.ytimg.com/vi/FlWAWSe0XyQ/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT50S',
#   'view_count': '77',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'y-TV0YQBMHI',
#   'video_name': 'Kanna moodi kittu innoru challenge Today winner is? 😁🤣😂 | Challenge no.22 | @MrandMrsYuviDhivi',
#   'channel_name': 'Mr and Mrs YuviDhivi',
#   'video_description': "@MrandMrsYuviDhivi\n\nContent creator | Blogger | traveller |\nDM/mail for promotion & collaboration \n\nFollow on Instagram page👇🏻 https://instagram.com/mr_and_mrs_yd?igshid=ZDc4ODBmNjlmNQ==\n\nFollow on Facebook page👇🏻\nhttps://www.facebook.com/profile.php?id=100094052390907&mibextid=ZbWKwL\n\nKanna moodi kittu innoru challenge Today winner is? 😁🤣😂 | Challenge no.22 | YD's challenge video | Tamil couples video | @Mr_and_Mrs_YuviDhivi\n\nChannel and copyright Disclaimer:-\n\nThis channel dose not promotes or encourages any illegal activities. All the things used in this video are toys only not weapons and nothing is real objects. No weapons were used. all the contents provided by this channel or this video is meant for fun and entertainment purposes only. this video no copyright infringement intended. our channel video and content are our teams own ideas only.\n\n#shorts #Challenge_no_22 #finding_challenge #eye_closing_challenge #tomato_challenge #find_on_correct_place_challenge #YDs_challenge_video #Challenge_video #Tamil_couples #Tamil_couples_video #Tamil_couples_comedy_video #comedy_video #Fun_and_entertainment_videos #couples_video #Tamil_video #YuviDhivi #mr_and_mrs_yd",
#   'published_at': '2023-07-30T14:30:29Z',
#   'thumbnail': 'https://i.ytimg.com/vi/y-TV0YQBMHI/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT1M',
#   'view_count': '528',
#   'like_count': '35',
#   'favourite_count': '0',
#   'comment_count': '4'},
#  {'video_id': 'WRdbFLIMBO4',
#   'video_name': '12 week transformation #bodybuilding #fitness #workout #gym #gymmotivation #maharashtra #motivation',
#   'channel_name': 'Sk Fit Feed ',
#   'video_description': '',
#   'published_at': '2024-02-07T01:40:17Z',
#   'thumbnail': 'https://i.ytimg.com/vi/WRdbFLIMBO4/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT23S',
#   'view_count': '70',
#   'like_count': '4',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': '7SXNbJebmv4',
#   'video_name': 'madurai malli @zanasamayal',
#   'channel_name': 'Zana samayal',
#   'video_description': '',
#   'published_at': '2024-02-11T11:08:06Z',
#   'thumbnail': 'https://i.ytimg.com/vi/7SXNbJebmv4/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT34S',
#   'view_count': '326',
#   'like_count': '11',
#   'favourite_count': '0',
#   'comment_count': '1'},
#  {'video_id': 'G4Db_ejo3jw',
#   'video_name': 'Mom and Daughter combo|PinkPearlsChennai',
#   'channel_name': 'Pink Pearls Chennai',
#   'video_description': 'Looking for Mom and Daughter combo????\n\nvisit www.facebook.com/Pinkpearlsclothing or whats app to 9884329333.\n\n#momanddaughtercombo #momanddaughterdance #momanddaughterdresses #custommade #customizeddress #internationalshipping #worldwideshipping #pinkpearlschennai',
#   'published_at': '2024-02-10T15:25:30Z',
#   'thumbnail': 'https://i.ytimg.com/vi/G4Db_ejo3jw/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT10S',
#   'view_count': '2511',
#   'like_count': '40',
#   'favourite_count': '0',
#   'comment_count': '0'},
#  {'video_id': 'Fo-Ckd9jQAw',
#   'video_name': 'Kerala cotton sarees |hand paint saree|Product description|Pink Pearls Chennai|Mompreneur|Online',
#   'channel_name': 'Pink Pearls Chennai',
#   'video_description': 'Kerala cotton hand paint sarees',
#   'published_at': '2020-07-21T11:46:30Z',
#   'thumbnail': 'https://i.ytimg.com/vi/Fo-Ckd9jQAw/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT2M18S',
#   'view_count': '10490',
#   'like_count': '168',
#   'favourite_count': '0',
#   'comment_count': '20'},
#  {'video_id': 'OMEAehSu3-g',
#   'video_name': '😲wow what a creative one ...naane shock aayitta itha paathu ...#shorts #trending #birthday #howto',
#   'channel_name': "Tharu's_passion",
#   'video_description': '',
#   'published_at': '2024-02-10T12:30:56Z',
#   'thumbnail': 'https://i.ytimg.com/vi/OMEAehSu3-g/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT1M',
#   'view_count': '540421',
#   'like_count': '37424',
#   'favourite_count': '0',
#   'comment_count': '55'},
#  {'video_id': 'C37h5jgau6M',
#   'video_name': 'new design of redvelvet ...#trendingshorts #howto #homemade #redvelvetcake',
#   'channel_name': "Tharu's_passion",
#   'video_description': '',
#   'published_at': '2023-06-19T12:27:24Z',
#   'thumbnail': 'https://i.ytimg.com/vi/C37h5jgau6M/default.jpg',
#   'caption_status': 'false',
#   'duration': 'PT1M',
#   'view_count': '3712',
#   'like_count': '37424',
#   'favourite_count': '0',
#   'comment_count': '3'}]

# %%
collections2 = db.comment_db
data1 = []
for i in collections2.find({},{'_id':0}):
    data1.append(i)
data1
# Out:
# [{'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyV-Rz_Eap3L9Y-oOh4AaABAg',
#   'Video_id': 'l0DA44CP1_Q',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Promo SM',
#   'Comment_author': '@norrisallison1725',
#   'Comment_published_date': '2024-01-31T19:50:11Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxKt7IxpWe2oG7Uls14AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'thats not bad',
#   'Comment_author': '@aarvibhandari8592',
#   'Comment_published_date': '2022-02-20T12:30:51Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx0hO-eqfBsLeQ4Kxx4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super da',
#   'Comment_author': '@danuslifestyle4514',
#   'Comment_published_date': '2021-05-13T05:31:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyQujTMe5OCN03_N9V4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Bro ennoda channela check panni parunga bro',
#   'Comment_author': '@rukbytes',
#   'Comment_published_date': '2021-05-05T10:00:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy09dNIla0eSZmGwzd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@gnanaseelan9754',
#   'Comment_published_date': '2021-05-03T09:23:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq6lnp6zSfbRxnH754AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Semma anna',
#   'Comment_author': '@mama_papa_official',
#   'Comment_published_date': '2021-04-30T04:01:47Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxD7D4ZXahYr-wJ7Hp4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice bro',
#   'Comment_author': '@user-gn6vz1yx6f',
#   'Comment_published_date': '2021-04-21T07:16:25Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwuq68Bc_npbs6OPbd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nanum 8th patikum pothu drawing panna <br>Then pona years lockdown to ipo vara drawing pandra<br>Yanaku yan drawings upload pannum aasai but crt video yadukka vara matinguthu',
#   'Comment_author': '@rokiniarumugam7394',
#   'Comment_published_date': '2021-04-07T01:41:08Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxU0yFNVGOgvbG5SDh4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'I will small age emotion',
#   'Comment_author': '@mohanrajsuper5718',
#   'Comment_published_date': '2021-02-26T08:44:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCObrG6gJprbPwbbF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Agmark 90&#39;s kid',
#   'Comment_author': '@devakirubai7161',
#   'Comment_published_date': '2021-02-16T15:44:14Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxv5pbAtNk2QsClWIN4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@prithipamarimuthu1514',
#   'Comment_published_date': '2020-11-28T06:24:50Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqL5-6D8X5ETN1HJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@tamilcrafternirmalkumar491',
#   'Comment_published_date': '2020-10-07T18:30:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3ojPHOFDB7EudCHF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice da 😂❤️',
#   'Comment_author': '@vigneshsrinivasan5094',
#   'Comment_published_date': '2020-08-26T16:07:14Z',
#   'Like_count': 2,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugw1o1MsUQsli-KdayJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super bro',
#   'Comment_author': '@harishkumar27.___',
#   'Comment_published_date': '2020-08-26T03:51:51Z',
#   'Like_count': 2,
#   'Reply_count': 2},
#  {'Comment_id': 'UgxKt7IxpWe2oG7Uls14AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'thats not bad',
#   'Comment_author': '@aarvibhandari8592',
#   'Comment_published_date': '2022-02-20T12:30:51Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx0hO-eqfBsLeQ4Kxx4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super da',
#   'Comment_author': '@danuslifestyle4514',
#   'Comment_published_date': '2021-05-13T05:31:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyQujTMe5OCN03_N9V4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Bro ennoda channela check panni parunga bro',
#   'Comment_author': '@rukbytes',
#   'Comment_published_date': '2021-05-05T10:00:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy09dNIla0eSZmGwzd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@gnanaseelan9754',
#   'Comment_published_date': '2021-05-03T09:23:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq6lnp6zSfbRxnH754AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Semma anna',
#   'Comment_author': '@mama_papa_official',
#   'Comment_published_date': '2021-04-30T04:01:47Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxD7D4ZXahYr-wJ7Hp4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice bro',
#   'Comment_author': '@user-gn6vz1yx6f',
#   'Comment_published_date': '2021-04-21T07:16:25Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwuq68Bc_npbs6OPbd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nanum 8th patikum pothu drawing panna <br>Then pona years lockdown to ipo vara drawing pandra<br>Yanaku yan drawings upload pannum aasai but crt video yadukka vara matinguthu',
#   'Comment_author': '@rokiniarumugam7394',
#   'Comment_published_date': '2021-04-07T01:41:08Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxU0yFNVGOgvbG5SDh4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'I will small age emotion',
#   'Comment_author': '@mohanrajsuper5718',
#   'Comment_published_date': '2021-02-26T08:44:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCObrG6gJprbPwbbF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Agmark 90&#39;s kid',
#   'Comment_author': '@devakirubai7161',
#   'Comment_published_date': '2021-02-16T15:44:14Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxv5pbAtNk2QsClWIN4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@prithipamarimuthu1514',
#   'Comment_published_date': '2020-11-28T06:24:50Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqL5-6D8X5ETN1HJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@tamilcrafternirmalkumar491',
#   'Comment_published_date': '2020-10-07T18:30:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3ojPHOFDB7EudCHF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice da 😂❤️',
#   'Comment_author': '@vigneshsrinivasan5094',
#   'Comment_published_date': '2020-08-26T16:07:14Z',
#   'Like_count': 2,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugw1o1MsUQsli-KdayJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super bro',
#   'Comment_author': '@harishkumar27.___',
#   'Comment_published_date': '2020-08-26T03:51:51Z',
#   'Like_count': 2,
#   'Reply_count': 2},
#  {'Comment_id': 'UgxKt7IxpWe2oG7Uls14AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'thats not bad',
#   'Comment_author': '@aarvibhandari8592',
#   'Comment_published_date': '2022-02-20T12:30:51Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx0hO-eqfBsLeQ4Kxx4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super da',
#   'Comment_author': '@danuslifestyle4514',
#   'Comment_published_date': '2021-05-13T05:31:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyQujTMe5OCN03_N9V4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Bro ennoda channela check panni parunga bro',
#   'Comment_author': '@rukbytes',
#   'Comment_published_date': '2021-05-05T10:00:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy09dNIla0eSZmGwzd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@gnanaseelan9754',
#   'Comment_published_date': '2021-05-03T09:23:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq6lnp6zSfbRxnH754AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Semma anna',
#   'Comment_author': '@mama_papa_official',
#   'Comment_published_date': '2021-04-30T04:01:47Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxD7D4ZXahYr-wJ7Hp4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice bro',
#   'Comment_author': '@user-gn6vz1yx6f',
#   'Comment_published_date': '2021-04-21T07:16:25Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwuq68Bc_npbs6OPbd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nanum 8th patikum pothu drawing panna <br>Then pona years lockdown to ipo vara drawing pandra<br>Yanaku yan drawings upload pannum aasai but crt video yadukka vara matinguthu',
#   'Comment_author': '@rokiniarumugam7394',
#   'Comment_published_date': '2021-04-07T01:41:08Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxU0yFNVGOgvbG5SDh4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'I will small age emotion',
#   'Comment_author': '@mohanrajsuper5718',
#   'Comment_published_date': '2021-02-26T08:44:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCObrG6gJprbPwbbF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Agmark 90&#39;s kid',
#   'Comment_author': '@devakirubai7161',
#   'Comment_published_date': '2021-02-16T15:44:14Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxv5pbAtNk2QsClWIN4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@prithipamarimuthu1514',
#   'Comment_published_date': '2020-11-28T06:24:50Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqL5-6D8X5ETN1HJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@tamilcrafternirmalkumar491',
#   'Comment_published_date': '2020-10-07T18:30:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3ojPHOFDB7EudCHF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice da 😂❤️',
#   'Comment_author': '@vigneshsrinivasan5094',
#   'Comment_published_date': '2020-08-26T16:07:14Z',
#   'Like_count': 2,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugw1o1MsUQsli-KdayJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super bro',
#   'Comment_author': '@harishkumar27.___',
#   'Comment_published_date': '2020-08-26T03:51:51Z',
#   'Like_count': 2,
#   'Reply_count': 2},
#  {'Comment_id': 'UgxKt7IxpWe2oG7Uls14AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'thats not bad',
#   'Comment_author': '@aarvibhandari8592',
#   'Comment_published_date': '2022-02-20T12:30:51Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx0hO-eqfBsLeQ4Kxx4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super da',
#   'Comment_author': '@danuslifestyle4514',
#   'Comment_published_date': '2021-05-13T05:31:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyQujTMe5OCN03_N9V4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Bro ennoda channela check panni parunga bro',
#   'Comment_author': '@rukbytes',
#   'Comment_published_date': '2021-05-05T10:00:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy09dNIla0eSZmGwzd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@gnanaseelan9754',
#   'Comment_published_date': '2021-05-03T09:23:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq6lnp6zSfbRxnH754AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Semma anna',
#   'Comment_author': '@mama_papa_official',
#   'Comment_published_date': '2021-04-30T04:01:47Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxD7D4ZXahYr-wJ7Hp4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice bro',
#   'Comment_author': '@user-gn6vz1yx6f',
#   'Comment_published_date': '2021-04-21T07:16:25Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwuq68Bc_npbs6OPbd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nanum 8th patikum pothu drawing panna <br>Then pona years lockdown to ipo vara drawing pandra<br>Yanaku yan drawings upload pannum aasai but crt video yadukka vara matinguthu',
#   'Comment_author': '@rokiniarumugam7394',
#   'Comment_published_date': '2021-04-07T01:41:08Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxU0yFNVGOgvbG5SDh4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'I will small age emotion',
#   'Comment_author': '@mohanrajsuper5718',
#   'Comment_published_date': '2021-02-26T08:44:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCObrG6gJprbPwbbF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Agmark 90&#39;s kid',
#   'Comment_author': '@devakirubai7161',
#   'Comment_published_date': '2021-02-16T15:44:14Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxv5pbAtNk2QsClWIN4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@prithipamarimuthu1514',
#   'Comment_published_date': '2020-11-28T06:24:50Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqL5-6D8X5ETN1HJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@tamilcrafternirmalkumar491',
#   'Comment_published_date': '2020-10-07T18:30:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3ojPHOFDB7EudCHF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice da 😂❤️',
#   'Comment_author': '@vigneshsrinivasan5094',
#   'Comment_published_date': '2020-08-26T16:07:14Z',
#   'Like_count': 2,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugw1o1MsUQsli-KdayJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super bro',
#   'Comment_author': '@harishkumar27.___',
#   'Comment_published_date': '2020-08-26T03:51:51Z',
#   'Like_count': 2,
#   'Reply_count': 2},
#  {'Comment_id': 'UgxKt7IxpWe2oG7Uls14AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'thats not bad',
#   'Comment_author': '@aarvibhandari8592',
#   'Comment_published_date': '2022-02-20T12:30:51Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx0hO-eqfBsLeQ4Kxx4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super da',
#   'Comment_author': '@danuslifestyle4514',
#   'Comment_published_date': '2021-05-13T05:31:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyQujTMe5OCN03_N9V4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Bro ennoda channela check panni parunga bro',
#   'Comment_author': '@rukbytes',
#   'Comment_published_date': '2021-05-05T10:00:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy09dNIla0eSZmGwzd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@gnanaseelan9754',
#   'Comment_published_date': '2021-05-03T09:23:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq6lnp6zSfbRxnH754AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Semma anna',
#   'Comment_author': '@mama_papa_official',
#   'Comment_published_date': '2021-04-30T04:01:47Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxD7D4ZXahYr-wJ7Hp4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice bro',
#   'Comment_author': '@user-gn6vz1yx6f',
#   'Comment_published_date': '2021-04-21T07:16:25Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwuq68Bc_npbs6OPbd4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nanum 8th patikum pothu drawing panna <br>Then pona years lockdown to ipo vara drawing pandra<br>Yanaku yan drawings upload pannum aasai but crt video yadukka vara matinguthu',
#   'Comment_author': '@rokiniarumugam7394',
#   'Comment_published_date': '2021-04-07T01:41:08Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxU0yFNVGOgvbG5SDh4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'I will small age emotion',
#   'Comment_author': '@mohanrajsuper5718',
#   'Comment_published_date': '2021-02-26T08:44:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCObrG6gJprbPwbbF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Agmark 90&#39;s kid',
#   'Comment_author': '@devakirubai7161',
#   'Comment_published_date': '2021-02-16T15:44:14Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxv5pbAtNk2QsClWIN4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@prithipamarimuthu1514',
#   'Comment_published_date': '2020-11-28T06:24:50Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXqL5-6D8X5ETN1HJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice',
#   'Comment_author': '@tamilcrafternirmalkumar491',
#   'Comment_published_date': '2020-10-07T18:30:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3ojPHOFDB7EudCHF4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Nice da 😂❤️',
#   'Comment_author': '@vigneshsrinivasan5094',
#   'Comment_published_date': '2020-08-26T16:07:14Z',
#   'Like_count': 2,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugw1o1MsUQsli-KdayJ4AaABAg',
#   'Video_id': 'lh7ce9E5J64',
#   'channel_name': 'Aji Arts',
#   'Comment_text': 'Super bro',
#   'Comment_author': '@harishkumar27.___',
#   'Comment_published_date': '2020-08-26T03:51:51Z',
#   'Like_count': 2,
#   'Reply_count': 2},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxxoqUjlBYaDhrz8FR4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Madam nanum try panne spr ah erunthuchu... 🎉',
#   'Comment_author': '@rajavelc777',
#   'Comment_published_date': '2023-06-10T15:35:59Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx2NGXFRnvpv0w7u9B4AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Very nice',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-06-09T07:07:49Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwaGru8R62yzkskrW54AaABAg',
#   'Video_id': 'qIRiZBVZ1Jc',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Nice 🎉🎉🎉',
#   'Comment_author': '@clearstudywithme5659',
#   'Comment_published_date': '2023-06-08T16:00:21Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgzaLUwXMlfOteAuJjN4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Noodles 😊😊',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-29T08:40:13Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSodgnBwleXhKtmPB4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': '👌👌👌👌',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-26T05:40:10Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwni7dfc5_xmcD0S3R4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Super',
#   'Comment_author': '@MalarkodiK-xv1nf',
#   'Comment_published_date': '2023-05-25T16:42:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzaLUwXMlfOteAuJjN4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Noodles 😊😊',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-29T08:40:13Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSodgnBwleXhKtmPB4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': '👌👌👌👌',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-26T05:40:10Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwni7dfc5_xmcD0S3R4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Super',
#   'Comment_author': '@MalarkodiK-xv1nf',
#   'Comment_published_date': '2023-05-25T16:42:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzaLUwXMlfOteAuJjN4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Noodles 😊😊',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-29T08:40:13Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSodgnBwleXhKtmPB4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': '👌👌👌👌',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-26T05:40:10Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwni7dfc5_xmcD0S3R4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Super',
#   'Comment_author': '@MalarkodiK-xv1nf',
#   'Comment_published_date': '2023-05-25T16:42:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzaLUwXMlfOteAuJjN4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Noodles 😊😊',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-29T08:40:13Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSodgnBwleXhKtmPB4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': '👌👌👌👌',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-26T05:40:10Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwni7dfc5_xmcD0S3R4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Super',
#   'Comment_author': '@MalarkodiK-xv1nf',
#   'Comment_published_date': '2023-05-25T16:42:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzaLUwXMlfOteAuJjN4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Noodles 😊😊',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-29T08:40:13Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwSodgnBwleXhKtmPB4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': '👌👌👌👌',
#   'Comment_author': '@tamilthaia9115',
#   'Comment_published_date': '2023-05-26T05:40:10Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwni7dfc5_xmcD0S3R4AaABAg',
#   'Video_id': 'w03LQwHGOqo',
#   'channel_name': 'Lakshithakannan',
#   'Comment_text': 'Super',
#   'Comment_author': '@MalarkodiK-xv1nf',
#   'Comment_published_date': '2023-05-25T16:42:28Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw3Q86XGBel4kGjc9V4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Kadai enga iruku bro',
#   'Comment_author': '@_editing_center_ak9335',
#   'Comment_published_date': '2023-11-04T15:50:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyWeooCVQhOkpPbXkV4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤',
#   'Comment_author': '@user-bs5tz4xx8d',
#   'Comment_published_date': '2023-11-02T13:51:08Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyT3HxRdJ8N9TA_5V94AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_author': '@sivasankarans9594',
#   'Comment_published_date': '2023-10-30T02:01:54Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy5PTeEV2Vya3OqnRJ4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤❤❤❤❤',
#   'Comment_author': '@SelvamAmmukutty',
#   'Comment_published_date': '2023-10-27T09:29:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzgSjv-fbt0t1pt5nd4AaABAg',
#   'Video_id': 'a6QLHfJBz3c',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@AnithaMahi-yy9cn',
#   'Comment_published_date': '2023-10-25T11:58:17Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzW_Ef3Mdbtt4SQBm14AaABAg',
#   'Video_id': 'uKJhQntcf7I',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Phone number please',
#   'Comment_author': '@krishbhuvi1388',
#   'Comment_published_date': '2022-11-08T15:19:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzW_Ef3Mdbtt4SQBm14AaABAg',
#   'Video_id': 'uKJhQntcf7I',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Phone number please',
#   'Comment_author': '@krishbhuvi1388',
#   'Comment_published_date': '2022-11-08T15:19:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzW_Ef3Mdbtt4SQBm14AaABAg',
#   'Video_id': 'uKJhQntcf7I',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Phone number please',
#   'Comment_author': '@krishbhuvi1388',
#   'Comment_published_date': '2022-11-08T15:19:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzW_Ef3Mdbtt4SQBm14AaABAg',
#   'Video_id': 'uKJhQntcf7I',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Phone number please',
#   'Comment_author': '@krishbhuvi1388',
#   'Comment_published_date': '2022-11-08T15:19:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzW_Ef3Mdbtt4SQBm14AaABAg',
#   'Video_id': 'uKJhQntcf7I',
#   'channel_name': "Farester Vlog's",
#   'Comment_text': 'Phone number please',
#   'Comment_author': '@krishbhuvi1388',
#   'Comment_published_date': '2022-11-08T15:19:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxxv6g12PAuB9cyJ594AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'ஒரு அழகான ஸ்குட்டி பைக் விக்குது பாருங்க',
#   'Comment_author': '@Sundaramoorthi-jp8qx',
#   'Comment_published_date': '2024-02-11T12:00:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy6u8FLepz5O4bYerR4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi 😍',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2024-02-11T04:46:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM-4D2k17uYGZUoVZ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@suryaj3897',
#   'Comment_published_date': '2024-02-11T01:06:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCcwUW_vnWo9ahzkJ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Naan onnum summa sollalanga. Enaku unga kooda Kandipa duet pannanum. Because enaku idhuve oru dream ah iruku',
#   'Comment_author': '@sethromaneditz5593',
#   'Comment_published_date': '2024-02-10T18:48:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxxv6g12PAuB9cyJ594AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'ஒரு அழகான ஸ்குட்டி பைக் விக்குது பாருங்க',
#   'Comment_author': '@Sundaramoorthi-jp8qx',
#   'Comment_published_date': '2024-02-11T12:00:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy6u8FLepz5O4bYerR4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi 😍',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2024-02-11T04:46:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM-4D2k17uYGZUoVZ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@suryaj3897',
#   'Comment_published_date': '2024-02-11T01:06:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCcwUW_vnWo9ahzkJ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Naan onnum summa sollalanga. Enaku unga kooda Kandipa duet pannanum. Because enaku idhuve oru dream ah iruku',
#   'Comment_author': '@sethromaneditz5593',
#   'Comment_published_date': '2024-02-10T18:48:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxxv6g12PAuB9cyJ594AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'ஒரு அழகான ஸ்குட்டி பைக் விக்குது பாருங்க',
#   'Comment_author': '@Sundaramoorthi-jp8qx',
#   'Comment_published_date': '2024-02-11T12:00:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy6u8FLepz5O4bYerR4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi 😍',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2024-02-11T04:46:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM-4D2k17uYGZUoVZ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@suryaj3897',
#   'Comment_published_date': '2024-02-11T01:06:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCcwUW_vnWo9ahzkJ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Naan onnum summa sollalanga. Enaku unga kooda Kandipa duet pannanum. Because enaku idhuve oru dream ah iruku',
#   'Comment_author': '@sethromaneditz5593',
#   'Comment_published_date': '2024-02-10T18:48:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxxv6g12PAuB9cyJ594AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'ஒரு அழகான ஸ்குட்டி பைக் விக்குது பாருங்க',
#   'Comment_author': '@Sundaramoorthi-jp8qx',
#   'Comment_published_date': '2024-02-11T12:00:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy6u8FLepz5O4bYerR4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi 😍',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2024-02-11T04:46:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM-4D2k17uYGZUoVZ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@suryaj3897',
#   'Comment_published_date': '2024-02-11T01:06:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCcwUW_vnWo9ahzkJ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Naan onnum summa sollalanga. Enaku unga kooda Kandipa duet pannanum. Because enaku idhuve oru dream ah iruku',
#   'Comment_author': '@sethromaneditz5593',
#   'Comment_published_date': '2024-02-10T18:48:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxxv6g12PAuB9cyJ594AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'ஒரு அழகான ஸ்குட்டி பைக் விக்குது பாருங்க',
#   'Comment_author': '@Sundaramoorthi-jp8qx',
#   'Comment_published_date': '2024-02-11T12:00:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy6u8FLepz5O4bYerR4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi 😍',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2024-02-11T04:46:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyM-4D2k17uYGZUoVZ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤❤',
#   'Comment_author': '@suryaj3897',
#   'Comment_published_date': '2024-02-11T01:06:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzCcwUW_vnWo9ahzkJ4AaABAg',
#   'Video_id': 'o8fSEmtmrmY',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Naan onnum summa sollalanga. Enaku unga kooda Kandipa duet pannanum. Because enaku idhuve oru dream ah iruku',
#   'Comment_author': '@sethromaneditz5593',
#   'Comment_published_date': '2024-02-10T18:48:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwFs9rL11flu99CVid4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤love u',
#   'Comment_author': '@user-ro6ob7yh4o',
#   'Comment_published_date': '2024-01-31T07:12:17Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwefm4Ghl1CLp-SofR4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Wow super sister',
#   'Comment_author': '@LathaSaravanan-xm8ui',
#   'Comment_published_date': '2024-01-16T12:46:12Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxepQxpR63ZPWJDgZJ4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Bomma Madhuri irukinga',
#   'Comment_author': '@kingraja7688',
#   'Comment_published_date': '2024-01-13T07:10:49Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwwZEz4ivjjGPURCMV4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Ayyo konnutta 😊',
#   'Comment_author': '@KEGanime',
#   'Comment_published_date': '2024-01-02T19:12:53Z',
#   'Like_count': 4,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzZVXsJmhjo1Dm2rHF4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤❤',
#   'Comment_author': '@kisotharan5294',
#   'Comment_published_date': '2023-12-22T17:29:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxvq6d5-I5Ey9LWSit4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'You are 🥰 cute',
#   'Comment_author': '@MGPaisa1427',
#   'Comment_published_date': '2023-12-22T10:31:34Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwVPqIlhY7vDWoU58d4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Which cream triggers you like that 😮 why you not saying that',
#   'Comment_author': '@maybe491',
#   'Comment_published_date': '2023-12-09T10:56:57Z',
#   'Like_count': 0,
#   'Reply_count': 1},
#  {'Comment_id': 'UgycD2RU_Il8Jh3W7mB4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '👌👌👌👌👌⭐⭐⭐⭐⭐',
#   'Comment_author': '@sajith8192',
#   'Comment_published_date': '2023-11-28T04:41:23Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugys0BAmlgxGiqilOSx4AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'You are sooo cute sister 😊😊😊',
#   'Comment_author': '@Zarrin4497',
#   'Comment_published_date': '2023-11-27T02:49:23Z',
#   'Like_count': 22,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugym7q5rw8Lf6Xgpth14AaABAg',
#   'Video_id': '_jI5_3c90MA',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hi sis u coimbatore ahh',
# ...
#   'Comment_author': '@sugumarimari6888',
#   'Comment_published_date': '2023-08-23T16:00:54Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwV34tbgKk9dMrpx8J4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'அழகு',
#   'Comment_author': '@DineshkumarS-xe9tl',
#   'Comment_published_date': '2023-07-04T15:55:34Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzd54CuikjH0sjILih4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Happy bday ji',
#   'Comment_author': '@venkatkarthi9033',
#   'Comment_published_date': '2023-06-26T16:38:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxpO2UG6zfUUNDPbxx4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'uppu podaarha biriyani 🤣🤣🤣',
#   'Comment_author': '@josephtony9866',
#   'Comment_published_date': '2023-06-25T15:25:08Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzA2uTaTql1eDTh7Hx4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'love you da',
#   'Comment_author': '@josephtony9866',
#   'Comment_published_date': '2023-06-25T15:24:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxwevuJOjoYnZmGpAd4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'I support us',
#   'Comment_author': '@firzyfox',
#   'Comment_published_date': '2023-05-12T13:00:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxybZy4zvmcmJgb5rt4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '😂😂😂',
#   'Comment_author': '@johnwilliam7766',
#   'Comment_published_date': '2023-05-04T20:49:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxVjShH4KXVzP6F9ll4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Saranampatti. Ahhhh🤔',
#   'Comment_author': '@demonsofnature8508',
#   'Comment_published_date': '2023-05-04T15:13:20Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugz_rwsFr-wzYZfoxM14AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Pls iniyavathu ungaloda intha seyala mathunga....❤❤❤',
#   'Comment_author': '@vigneshradan1315',
#   'Comment_published_date': '2023-05-03T18:25:51Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyExTru9bJnXMmxId94AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Neenga piriyani pathi podama dosa pathi mattum potrukalam...ungala oruthar manasuvalikiramathiri pesum pothu epdi irukkumo athea mathirithan antha piriyani kadakaru and piriyani samachavangalukku irukkummm....',
#   'Comment_author': '@vigneshradan1315',
#   'Comment_published_date': '2023-05-03T18:24:52Z',
#   'Like_count': 0,
#   'Reply_count': 1},
#  {'Comment_id': 'UgzWC7gwoZGTM5iiL014AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Will you marry me dear❤',
#   'Comment_author': '@TnpscThulasiAcademy',
#   'Comment_published_date': '2023-05-01T21:06:17Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzwsPJ9Gu9W9EEbhbl4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Nengale sapta eppadi enakku ellam kidaiyatha',
#   'Comment_author': '@jayaram.s6448',
#   'Comment_published_date': '2023-04-30T14:01:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwHpUVH1TzYO8-LzMt4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Nice darling',
#   'Comment_author': '@ponnaiyanthangavelu1701',
#   'Comment_published_date': '2023-04-25T15:23:18Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugx9tzpOxe0shlgsJq54AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'செம்ம அழகு நீங்க i love you ❤❤❤',
#   'Comment_author': '@halithhassan1905',
#   'Comment_published_date': '2023-04-24T21:40:24Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxLD_dIWowx1uQUwYx4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'I LOVE YOU',
#   'Comment_author': '@ponnuvel234',
#   'Comment_published_date': '2023-04-22T14:57:35Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwNU9ElFQOX_gz_LXl4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hi',
#   'Comment_author': '@kltambias7557',
#   'Comment_published_date': '2023-04-19T23:00:48Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyXvOMHP7WB4221FRF4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Nenga nama Coimbatore thana sama 👍 nama friends okay va ❤️',
#   'Comment_author': '@thenumozhi9905',
#   'Comment_published_date': '2023-04-19T03:05:16Z',
#   'Like_count': 4,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxfVpPVMRGVn2iaGr94AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hi',
#   'Comment_author': '@SivappaSiva-fj1qq',
#   'Comment_published_date': '2023-04-18T17:50:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwuqEcHncUu7T2Hmc14AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'I love you da',
#   'Comment_author': '@vinithailayaraja9271',
#   'Comment_published_date': '2023-04-16T08:46:21Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugxh-Ms9fIkCvqF9p214AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'U💛💛💛💛💛💛💛💛💛💛💛🤷',
#   'Comment_author': '@RameshRamesh-ub4hu',
#   'Comment_published_date': '2023-04-14T17:05:58Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugwu8Iz2f1XFPN86lj54AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'chechi dance video cheyyy...',
#   'Comment_author': '@appumg4792',
#   'Comment_published_date': '2023-04-11T18:19:03Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyH046wH4a696_IrzF4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hello....❤❤❤❤',
#   'Comment_author': '@riyasri4374',
#   'Comment_published_date': '2023-04-08T16:58:13Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyg8g2zFiCxlkWqT0Z4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '👌👌👌👌😍😘',
#   'Comment_author': '@tendulkerm5988',
#   'Comment_published_date': '2023-04-08T04:31:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyI3TJWvBl3msFaZ-B4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hai I am mohan ❤❤',
#   'Comment_author': '@MohanMohan-hw7zz',
#   'Comment_published_date': '2023-04-01T18:06:00Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzPjp1WgLTa0o_VCSJ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Rish ah pakkum pothe thriyuthu. Priyani😢',
#   'Comment_author': '@vadivelvadivel8761',
#   'Comment_published_date': '2023-03-29T05:05:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzXic-mNICWWGJlEcF4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '💕Your Admirer 💕',
#   'Comment_author': '@prasy8614',
#   'Comment_published_date': '2023-03-24T12:52:53Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwUAhkrt5cK1TGMykp4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Nice info',
#   'Comment_author': '@channelno0014',
#   'Comment_published_date': '2023-03-17T17:08:37Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwjzNkBe767ANF_zgh4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'super divya 💞💯❤❤',
#   'Comment_author': '@vigneshkumar607',
#   'Comment_published_date': '2023-03-13T19:19:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyuKLy5nT9jJxYiQhJ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'akka you are very beautiful and you are very like pasean',
#   'Comment_author': '@narashimanbalaji9835',
#   'Comment_published_date': '2023-03-08T09:18:57Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzaKKcvZpb8cpqw8Tt4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Enna Ponnu ne pada  padanu pesura',
#   'Comment_author': '@nkarthik1330',
#   'Comment_published_date': '2023-03-07T16:19:28Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwTt75rp9eSg4dP4nd4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'semma fun lovely 💕',
#   'Comment_author': '@yredit8309',
#   'Comment_published_date': '2023-03-06T17:24:35Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgyTFIV4m6lSRYUiqVh4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hello beauty 😍',
#   'Comment_author': '@zvsr1257',
#   'Comment_published_date': '2023-03-06T11:49:49Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwE_nwwL55-TEvVTad4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Super',
#   'Comment_author': '@sopiaranisopiarani331',
#   'Comment_published_date': '2023-03-06T11:20:52Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyu6EQ3AIsnUzc1ibV4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '❤️❤️❤️',
#   'Comment_author': '@seenusasi9562',
#   'Comment_published_date': '2023-03-05T09:38:55Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgznAuJBU5FEuY1UEkR4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hii akka your looking so cute ❤️😘',
#   'Comment_author': '@raashida7068',
#   'Comment_published_date': '2023-03-02T08:12:40Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzlt43Ep9gOVy5J30l4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Hii I&#39;m A big fan of you ....',
#   'Comment_author': '@vijayelumalai3037',
#   'Comment_published_date': '2023-03-01T14:37:31Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwlD91SQwgFIXt9eW54AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Your interview is so inspiration for all girls keep it up 😊❤️😊 my sis also your fan',
#   'Comment_author': '@SDM-wu5il',
#   'Comment_published_date': '2023-03-01T10:27:04Z',
#   'Like_count': 23,
#   'Reply_count': 1},
#  {'Comment_id': 'UgyDTxtPfedyY2UeLBB4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Sister oru content tharen pandringala upcoming videos la',
#   'Comment_author': '@WashingMachineDLIWashingmachin',
#   'Comment_published_date': '2023-02-28T21:42:00Z',
#   'Like_count': 7,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzVvaE_PlVAeJkT9wZ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Nalla erunga sister',
#   'Comment_author': '@bharathimathi2636',
#   'Comment_published_date': '2023-02-28T14:03:44Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugyw6e8vh62O99HcPQZ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '😍😍😍',
#   'Comment_author': '@rameshdarshan895',
#   'Comment_published_date': '2023-02-28T13:52:04Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxOZbAbxZefs2fXWZJ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Unga Instagram I&#39;d. Mention panunga pls',
#   'Comment_author': '@tnrooster1078',
#   'Comment_published_date': '2023-02-28T12:41:43Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw-4NYGTOoIT-gqMEV4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'All the best in life amma 👍',
#   'Comment_author': '@kabilvigneshn2387',
#   'Comment_published_date': '2023-02-28T11:39:13Z',
#   'Like_count': 9,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugynj-xZVsVPmklAz_R4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Angel',
#   'Comment_author': '@aazaaaazaa6070',
#   'Comment_published_date': '2023-02-28T08:19:51Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy3wH3x-NpdhkMmItB4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Worth ah illaya sister 🙄🙄🙄',
#   'Comment_author': '@badriBN333',
#   'Comment_published_date': '2023-02-28T04:56:20Z',
#   'Like_count': 1,
#   'Reply_count': 1},
#  {'Comment_id': 'UgxIuAwFZqJyeFZ8USh4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Cute😍',
#   'Comment_author': '@artist_tamil_',
#   'Comment_published_date': '2023-02-27T17:42:52Z',
#   'Like_count': 4,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy_ABVhQXwXNywXqRV4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'akka love from Sri lanka',
#   'Comment_author': '@Joker-rw1wr',
#   'Comment_published_date': '2023-02-25T01:53:37Z',
#   'Like_count': 43,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugzq5KO9A47mBCwIY7p4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Alagu da thango ❤️❤️❤️',
#   'Comment_author': '@pothu8784',
#   'Comment_published_date': '2023-02-23T11:36:09Z',
#   'Like_count': 25,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzeRIV53aXaEtwtoqx4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Seeiyasa neenka sappiratha pakka asaya irukku from sri lanka',
#   'Comment_author': '@kisanthisivarasa2601',
#   'Comment_published_date': '2023-02-22T13:42:45Z',
#   'Like_count': 7,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwARg95Dj3U9QlpizF4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Super 😀',
#   'Comment_author': '@sajsaj3058',
#   'Comment_published_date': '2023-02-22T11:02:04Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw5fE_3YOObJHoeBu14AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Div-----❤❤❤❤',
#   'Comment_author': '@sajithkolleri',
#   'Comment_published_date': '2023-02-07T17:57:56Z',
#   'Like_count': 2,
#   'Reply_count': 0},
#  {'Comment_id': 'UgxHMbBGJg_zdwgd9mt4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Vera level',
#   'Comment_author': '@yesh6785',
#   'Comment_published_date': '2022-10-04T17:13:13Z',
#   'Like_count': 5,
#   'Reply_count': 1},
#  {'Comment_id': 'Ugyd2STkXTRZokawH-Z4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Super sister🎉🎉🎉',
#   'Comment_author': '@anuga.v7577',
#   'Comment_published_date': '2024-01-21T10:56:26Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugw4rKdBoSHfsWsMWll4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'Cute akkA',
#   'Comment_author': '@rvarunkumar7arollno228',
#   'Comment_published_date': '2024-01-13T08:31:00Z',
#   'Like_count': 1,
#   'Reply_count': 0},
#  {'Comment_id': 'UgzQGGyi8lW3zPyB6PB4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'What happen to her skin',
#   'Comment_author': '@SoniyaSaragadam',
#   'Comment_published_date': '2024-01-07T04:21:33Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'Ugy0SEs5A9Gj-Zu7PBZ4AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': 'hi cutea irukingha ❤',
#   'Comment_author': '@user-uc6lc1sc6h',
#   'Comment_published_date': '2023-12-21T15:16:42Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  {'Comment_id': 'UgwHge_sOnD2vQ7qVg14AaABAg',
#   'Video_id': 'NsdOqt_V2Nw',
#   'channel_name': 'Divyalakshmi',
#   'Comment_text': '😢😢😢😢😢',
#   'Comment_author': '@karthikeyannarayanasamy1950',
#   'Comment_published_date': '2023-11-20T18:01:53Z',
#   'Like_count': 0,
#   'Reply_count': 0},
#  ...]

# %%
import pymysql as sql
mydb = sql.connect(host="localhost",port=3306,
                        user="root",
                        password="admin@123",database="youtube_db")
mycur = mydb.cursor()

# %%
import pymongo
client = pymongo.MongoClient('mongodb://localhost:27017')    
db = client['youtube_db']

# %%
mycur.execute("alter table channel modify column channel_description TEXT")

# %%
info1 = db.channel_db

query = "INSERT INTO channel(channel_name,channel_id,playlist_id,subs_count,view_count,channel_description,total_videos) VALUES(%s,%s,%s,%s,%s,%s,%s)"
                
for i in info1.find({},{'_id':0}):
    mycur.execute(query,tuple(i.values()))
    mydb.commit()

# %%
mycur.execute("alter table video modify column published_date VARCHAR(255)")

# %%
mycur.execute("alter table comment1 modify column comment_published_date VARCHAR(255)")
# Out:
# 0

# %%
mycur.execute("alter table video modify column duration VARCHAR(255)")
# Out:
# 0

# %%
info2 = db.video_db

query = "INSERT INTO video(video_id,video_name,channel_name,video_description,published_date,thumbnail,caption_status,duration,view_count,like_count,favourite_count,comment_count) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
                
for i in info2.find({},{'_id':0}):
    mycur.execute(query,tuple(i.values()))
    mydb.commit()

# %%
mycur.execute("truncate table comment1")
# Out:
# 0

# %%
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
info3 = db.comment_db

query = "INSERT INTO comment1(comment_id,video_id,channel_name,comment_text,comment_author,comment_published_date,like_count,reply_count) VALUES(%s,%s,%s,%s,%s,%s,%s,%s)"
                
for i in info3.find({},{'_id':0}):
    mycur.execute(query,tuple(i.values()))
    mydb.commit()

# %%
#question 1:
df = pd.read_sql_query("select video_name,channel_name from video order by channel_name",mydb)
#st.write(df)
df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\2450830454.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("select video_name,channel_name from video order by channel_name",mydb)
#                                            video_name          channel_name
# 0                Rahul M Leaf Art🍃 | Aji Arts #shorts              Aji Arts
# 1                Rahul M Leaf Art🍃 | Aji Arts #shorts              Aji Arts
# 2                Rahul M Leaf Art🍃 | Aji Arts #shorts              Aji Arts
# 3   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 4   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 5   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 6   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 7   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 8   Passion to learn.. #shorts #learning #scooty #...         Dheekshutimes
# 9   SS Motors - Used Two Wheelers Branches: Sarava...          Divyalakshmi
# 10     Madurai Famous Iyer Tiffin ❣️🔥#madurai #foodie       Farester Vlog's
# 11       sappadu comedy...fun..new.. food..tasty..veg       Lakshithakannan
# 12  roatukadai style podi dosa|| dosa recipe.. foo...       Lakshithakannan
# 13  irukka illaya challenge | challenge no.147 #sh...  Mr and Mrs YuviDhivi
# 14  Kanna moodi kittu innoru challenge Today winne...  Mr and Mrs YuviDhivi
# 15           Mom and Daughter combo|PinkPearlsChennai   Pink Pearls Chennai
# 16  Kerala cotton sarees |hand paint saree|Product...   Pink Pearls Chennai
# 17  12 week transformation #bodybuilding #fitness ...          Sk Fit Feed
# 18  😲wow what a creative one ...naane shock aayitt...       Tharu's_passion
# 19  new design of redvelvet ...#trendingshorts #ho...       Tharu's_passion
# 20                         madurai malli @zanasamayal          Zana samayal

# %%
#question 2.
df = pd.read_sql_query("select total_videos,channel_name from channel order by total_videos desc",mydb)
#st.write(df)
fig = px.bar(df,x='channel_name',y='total_videos',orientation='v',color='channel_name')
st.plotly_chart(fig,use_container_width = True)
fig
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\3185472706.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# <div>                            <div id="0fea397c-f329-495c-96bd-28331e4258ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fea397c-f329-495c-96bd-28331e4258ce")) {                    Plotly.newPlot(                        "0fea397c-f329-495c-96bd-28331e4258ce",                        [{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Lakshithakannan","marker":{"color":"#000001","pattern":{"shape":""}},"name":"Lakshithakannan","offsetgroup":"Lakshithakannan","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshithakannan"],"xaxis":"x","y":[281],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Tharu's_passion","marker":{"color":"#000002","pattern":{"shape":""}},"name":"Tharu's_passion","offsetgroup":"Tharu's_passion","orientation":"v","showlegend":true,"textposition":"auto","x":["Tharu's_passion"],"xaxis":"x","y":[228],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Mr and Mrs YuviDhivi","marker":{"color":"#000003","pattern":{"shape":""}},"name":"Mr and Mrs YuviDhivi","offsetgroup":"Mr and Mrs YuviDhivi","orientation":"v","showlegend":true,"textposition":"auto","x":["Mr and Mrs YuviDhivi"],"xaxis":"x","y":[227],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Pink Pearls Chennai","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Pink Pearls Chennai","offsetgroup":"Pink Pearls Chennai","orientation":"v","showlegend":true,"textposition":"auto","x":["Pink Pearls Chennai"],"xaxis":"x","y":[208],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Farester Vlog's","marker":{"color":"#000005","pattern":{"shape":""}},"name":"Farester Vlog's","offsetgroup":"Farester Vlog's","orientation":"v","showlegend":true,"textposition":"auto","x":["Farester Vlog's"],"xaxis":"x","y":[181],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Divyalakshmi","marker":{"color":"#000006","pattern":{"shape":""}},"name":"Divyalakshmi","offsetgroup":"Divyalakshmi","orientation":"v","showlegend":true,"textposition":"auto","x":["Divyalakshmi"],"xaxis":"x","y":[155],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Zana samayal","marker":{"color":"#000007","pattern":{"shape":""}},"name":"Zana samayal","offsetgroup":"Zana samayal","orientation":"v","showlegend":true,"textposition":"auto","x":["Zana samayal"],"xaxis":"x","y":[152],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Aji Arts","marker":{"color":"#000008","pattern":{"shape":""}},"name":"Aji Arts","offsetgroup":"Aji Arts","orientation":"v","showlegend":true,"textposition":"auto","x":["Aji Arts"],"xaxis":"x","y":[119],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Dheekshutimes","marker":{"color":"#000009","pattern":{"shape":""}},"name":"Dheekshutimes","offsetgroup":"Dheekshutimes","orientation":"v","showlegend":true,"textposition":"auto","x":["Dheekshutimes"],"xaxis":"x","y":[76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>total_videos=%{y}<extra></extra>","legendgroup":"Sk Fit Feed ","marker":{"color":"#000010","pattern":{"shape":""}},"nam ...

# %%
#question 3.
df = pd.read_sql_query("select view_count , channel_name from video order by view_count desc limit 10",mydb)
#st.write(df)
fig = px.bar(df,x='channel_name',y='view_count',orientation='h',color='channel_name')
st.plotly_chart(fig,use_container_width = True)
fig
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\1214701124.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# <div>                            <div id="77aa572c-a096-4e6a-a36e-89e2af267b8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77aa572c-a096-4e6a-a36e-89e2af267b8f")) {                    Plotly.newPlot(                        "77aa572c-a096-4e6a-a36e-89e2af267b8f",                        [{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Tharu's_passion","marker":{"color":"#000001","pattern":{"shape":""}},"name":"Tharu's_passion","offsetgroup":"Tharu's_passion","orientation":"h","showlegend":true,"textposition":"auto","x":["Tharu's_passion","Tharu's_passion"],"xaxis":"x","y":[540421,3712],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Pink Pearls Chennai","marker":{"color":"#000002","pattern":{"shape":""}},"name":"Pink Pearls Chennai","offsetgroup":"Pink Pearls Chennai","orientation":"h","showlegend":true,"textposition":"auto","x":["Pink Pearls Chennai","Pink Pearls Chennai"],"xaxis":"x","y":[10490,2511],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Lakshithakannan","marker":{"color":"#000003","pattern":{"shape":""}},"name":"Lakshithakannan","offsetgroup":"Lakshithakannan","orientation":"h","showlegend":true,"textposition":"auto","x":["Lakshithakannan","Lakshithakannan"],"xaxis":"x","y":[3555,943],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Divyalakshmi","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Divyalakshmi","offsetgroup":"Divyalakshmi","orientation":"h","showlegend":true,"textposition":"auto","x":["Divyalakshmi"],"xaxis":"x","y":[2782],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Mr and Mrs YuviDhivi","marker":{"color":"#000005","pattern":{"shape":""}},"name":"Mr and Mrs YuviDhivi","offsetgroup":"Mr and Mrs YuviDhivi","orientation":"h","showlegend":true,"textposition":"auto","x":["Mr and Mrs YuviDhivi"],"xaxis":"x","y":[528],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Farester Vlog's","marker":{"color":"#000006","pattern":{"shape":""}},"name":"Farester Vlog's","offsetgroup":"Farester Vlog's","orientation":"h","showlegend":true,"textposition":"auto","x":["Farester Vlog's"],"xaxis":"x","y":[458],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Zana samayal","marker":{"color":"#000007","pattern":{"shape":""}},"name":"Zana samayal","offsetgroup":"Zana samayal","orientation":"h","showlegend":true,"textposition":"auto","x":["Zana samayal"],"xaxis":"x","y":[326],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"candlestick":[{"decreasing":{"line":{"color":"#000033"}},"increasing":{"line":{"color":"#000032"}},"type":"candlestick"}],"contourcarpet":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contourcarpet"}],"contour":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"t ...
#
# var gd = document.getElementById('77aa572c-a096-4e6a-a36e-89e2af267b8f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
#question 4.
df = pd.read_sql_query("select comment_count,video_name,channel_name from video",mydb)
#st.write(df)
fig = px.bar(df,x='channel_name',y='comment_count',color ='channel_name')
#st.plotly_chart(fig)
df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\1605553240.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#     comment_count                                         video_name  \
# 0               0               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 1               0               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 2               0               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 3               0       sappadu comedy...fun..new.. food..tasty..veg
# 4               4  roatukadai style podi dosa|| dosa recipe.. foo...
# 5               0     Madurai Famous Iyer Tiffin ❣️🔥#madurai #foodie
# 6               4  SS Motors - Used Two Wheelers Branches: Sarava...
# 7               4  Passion to learn.. #shorts #learning #scooty #...
# 8               4  Passion to learn.. #shorts #learning #scooty #...
# 9               4  Passion to learn.. #shorts #learning #scooty #...
# 10              4  Passion to learn.. #shorts #learning #scooty #...
# 11              4  Passion to learn.. #shorts #learning #scooty #...
# 12              4  Passion to learn.. #shorts #learning #scooty #...
# 13              0  irukka illaya challenge | challenge no.147 #sh...
# 14              4  Kanna moodi kittu innoru challenge Today winne...
# 15              0  12 week transformation #bodybuilding #fitness ...
# 16              1                         madurai malli @zanasamayal
# 17              0           Mom and Daughter combo|PinkPearlsChennai
# 18             20  Kerala cotton sarees |hand paint saree|Product...
# 19             55  😲wow what a creative one ...naane shock aayitt...
# 20              3  new design of redvelvet ...#trendingshorts #ho...
#
#             channel_name
# 0               Aji Arts
# 1               Aji Arts
# 2               Aji Arts
# 3        Lakshithakannan
# 4        Lakshithakannan
# 5        Farester Vlog's
# 6           Divyalakshmi
# 7          Dheekshutimes
# 8          Dheekshutimes
# 9          Dheekshutimes
# 10         Dheekshutimes
# 11         Dheekshutimes
# 12         Dheekshutimes
# 13  Mr and Mrs YuviDhivi
# 14  Mr and Mrs YuviDhivi
# 15          Sk Fit Feed
# 16          Zana samayal
# 17   Pink Pearls Chennai
# 18   Pink Pearls Chennai
# 19       Tharu's_passion
# 20       Tharu's_passion

# %%
#question 5.
df = pd.read_sql_query("select like_count,video_name,channel_name from video order by like_count desc",mydb)
#st.write(df)
fig=px.bar(df,x='video_name',y='like_count',color='channel_name')
#st.plotly_chart(fig)
df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\1021435866.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#     like_count                                         video_name  \
# 0        37424  😲wow what a creative one ...naane shock aayitt...
# 1        37424  new design of redvelvet ...#trendingshorts #ho...
# 2          218     Madurai Famous Iyer Tiffin ❣️🔥#madurai #foodie
# 3          168  SS Motors - Used Two Wheelers Branches: Sarava...
# 4          168  Passion to learn.. #shorts #learning #scooty #...
# 5          168  Passion to learn.. #shorts #learning #scooty #...
# 6          168  Passion to learn.. #shorts #learning #scooty #...
# 7          168  Passion to learn.. #shorts #learning #scooty #...
# 8          168  Passion to learn.. #shorts #learning #scooty #...
# 9          168  Passion to learn.. #shorts #learning #scooty #...
# 10         168  irukka illaya challenge | challenge no.147 #sh...
# 11         168  Kerala cotton sarees |hand paint saree|Product...
# 12          81       sappadu comedy...fun..new.. food..tasty..veg
# 13          40           Mom and Daughter combo|PinkPearlsChennai
# 14          35  Kanna moodi kittu innoru challenge Today winne...
# 15          27  roatukadai style podi dosa|| dosa recipe.. foo...
# 16          12               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 17          12               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 18          12               Rahul M Leaf Art🍃 | Aji Arts #shorts
# 19          11                         madurai malli @zanasamayal
# 20           4  12 week transformation #bodybuilding #fitness ...
#
#             channel_name
# 0        Tharu's_passion
# 1        Tharu's_passion
# 2        Farester Vlog's
# 3           Divyalakshmi
# 4          Dheekshutimes
# 5          Dheekshutimes
# 6          Dheekshutimes
# 7          Dheekshutimes
# 8          Dheekshutimes
# 9          Dheekshutimes
# 10  Mr and Mrs YuviDhivi
# 11   Pink Pearls Chennai
# 12       Lakshithakannan
# 13   Pink Pearls Chennai
# 14  Mr and Mrs YuviDhivi
# 15       Lakshithakannan
# 16              Aji Arts
# 17              Aji Arts
# 18              Aji Arts
# 19          Zana samayal
# 20          Sk Fit Feed

# %%
#question 6.
df = pd.read_sql_query("select view_count,channel_name from channel order by view_count desc",mydb)
#st.write(df)
fig = px.bar(df,x='channel_name',y='view_count',color='channel_name')
#st.plotly_chart(fig)
fig
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\3039402958.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# <div>                            <div id="3f67e579-8fa3-4d45-9023-cd2414c63438" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f67e579-8fa3-4d45-9023-cd2414c63438")) {                    Plotly.newPlot(                        "3f67e579-8fa3-4d45-9023-cd2414c63438",                        [{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Tharu's_passion","marker":{"color":"#000001","pattern":{"shape":""}},"name":"Tharu's_passion","offsetgroup":"Tharu's_passion","orientation":"v","showlegend":true,"textposition":"auto","x":["Tharu's_passion"],"xaxis":"x","y":[248751930],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Divyalakshmi","marker":{"color":"#000002","pattern":{"shape":""}},"name":"Divyalakshmi","offsetgroup":"Divyalakshmi","orientation":"v","showlegend":true,"textposition":"auto","x":["Divyalakshmi"],"xaxis":"x","y":[68151742],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Farester Vlog's","marker":{"color":"#000003","pattern":{"shape":""}},"name":"Farester Vlog's","offsetgroup":"Farester Vlog's","orientation":"v","showlegend":true,"textposition":"auto","x":["Farester Vlog's"],"xaxis":"x","y":[21055457],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Aji Arts","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Aji Arts","offsetgroup":"Aji Arts","orientation":"v","showlegend":true,"textposition":"auto","x":["Aji Arts"],"xaxis":"x","y":[859639],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Lakshithakannan","marker":{"color":"#000005","pattern":{"shape":""}},"name":"Lakshithakannan","offsetgroup":"Lakshithakannan","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshithakannan"],"xaxis":"x","y":[490591],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Mr and Mrs YuviDhivi","marker":{"color":"#000006","pattern":{"shape":""}},"name":"Mr and Mrs YuviDhivi","offsetgroup":"Mr and Mrs YuviDhivi","orientation":"v","showlegend":true,"textposition":"auto","x":["Mr and Mrs YuviDhivi"],"xaxis":"x","y":[225100],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Zana samayal","marker":{"color":"#000007","pattern":{"shape":""}},"name":"Zana samayal","offsetgroup":"Zana samayal","orientation":"v","showlegend":true,"textposition":"auto","x":["Zana samayal"],"xaxis":"x","y":[89190],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Pink Pearls Chennai","marker":{"color":"#000008","pattern":{"shape":""}},"name":"Pink Pearls Chennai","offsetgroup":"Pink Pearls Chennai","orientation":"v","showlegend":true,"textposition":"auto","x":["Pink Pearls Chennai"],"xaxis":"x","y":[61660],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Dheekshutimes","marker":{"color":"#000009","pattern":{"shape":""}},"name":"Dheekshutimes","offsetgroup":"Dheekshutimes","orientation":"v","showlegend":true,"textposition":"auto","x":["Dheekshutimes"],"xaxis":"x","y":[36223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"Sk Fit Feed ","marker":{"color":"#000010","pattern":{"shap ...

# %%
#question 7.
df = pd.read_sql_query("select like_count,video_name, channel_name from video",mydb)
#st.write(df)
fig = px.bar(df,x='channel_name',y='like_count',color='channel_name')
#st.plotly_chart(fig)
fig
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\2473607483.py:1: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# <div>                            <div id="fffe30cd-b3d6-45dc-a523-c060ac64f3f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fffe30cd-b3d6-45dc-a523-c060ac64f3f3")) {                    Plotly.newPlot(                        "fffe30cd-b3d6-45dc-a523-c060ac64f3f3",                        [{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Aji Arts","marker":{"color":"#000001","pattern":{"shape":""}},"name":"Aji Arts","offsetgroup":"Aji Arts","orientation":"v","showlegend":true,"textposition":"auto","x":["Aji Arts","Aji Arts","Aji Arts"],"xaxis":"x","y":[12,12,12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Lakshithakannan","marker":{"color":"#000002","pattern":{"shape":""}},"name":"Lakshithakannan","offsetgroup":"Lakshithakannan","orientation":"v","showlegend":true,"textposition":"auto","x":["Lakshithakannan","Lakshithakannan"],"xaxis":"x","y":[81,27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Farester Vlog's","marker":{"color":"#000003","pattern":{"shape":""}},"name":"Farester Vlog's","offsetgroup":"Farester Vlog's","orientation":"v","showlegend":true,"textposition":"auto","x":["Farester Vlog's"],"xaxis":"x","y":[218],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Divyalakshmi","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Divyalakshmi","offsetgroup":"Divyalakshmi","orientation":"v","showlegend":true,"textposition":"auto","x":["Divyalakshmi"],"xaxis":"x","y":[168],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Dheekshutimes","marker":{"color":"#000005","pattern":{"shape":""}},"name":"Dheekshutimes","offsetgroup":"Dheekshutimes","orientation":"v","showlegend":true,"textposition":"auto","x":["Dheekshutimes","Dheekshutimes","Dheekshutimes","Dheekshutimes","Dheekshutimes","Dheekshutimes"],"xaxis":"x","y":[168,168,168,168,168,168],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Mr and Mrs YuviDhivi","marker":{"color":"#000006","pattern":{"shape":""}},"name":"Mr and Mrs YuviDhivi","offsetgroup":"Mr and Mrs YuviDhivi","orientation":"v","showlegend":true,"textposition":"auto","x":["Mr and Mrs YuviDhivi","Mr and Mrs YuviDhivi"],"xaxis":"x","y":[168,35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Sk Fit Feed ","marker":{"color":"#000007","pattern":{"shape":""}},"name":"Sk Fit Feed ","offsetgroup":"Sk Fit Feed ","orientation":"v","showlegend":true,"textposition":"auto","x":["Sk Fit Feed "],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Zana samayal","marker":{"color":"#000008","pattern":{"shape":""}},"name":"Zana samayal","offsetgroup":"Zana samayal","orientation":"v","showlegend":true,"textposition":"auto","x":["Zana samayal"],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"channel_name=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"Pink Pearls Chennai","marker":{"color":"#000009","pattern":{"shape":""}},"name":"Pink Pearls Chennai","offsetgroup":"Pink Pearls Chennai","orientation":"v","showlegend":true,"textposition":"auto","x":["Pink Pearls Chennai","Pink Pearls Chennai"],"xaxis":"x","y":[40,168],"yaxis":"y","type":"bar"},{"alignmentgroup ...

# %%
#question 8.
df = pd.read_sql_query("""SELECT channel_name FROM video 
                       WHERE published_date LIKE '2023%' 
                       GROUP BY channel_name
                       ORDER BY channel_name""",mydb)
#st.write(df)
#df1 = pd.read_sql_query("select Channel_name,Published_date from video_info",myconnect)
#fig = px.bar(df,x='channel_name',y='published_date',color ='channel_name')
#st.plotly_chart(fig)
df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\45259064.py:2: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#            channel_name
# 0       Lakshithakannan
# 1  Mr and Mrs YuviDhivi
# 2       Tharu's_passion

# %%
#question 9.
''''df = pd.read_sql_query(""""SELECT channel_name,
                            AVG(duration)/60 AS "Average_Video_Duration (mins)"
                            FROM video
                            GROUP BY channel_name
                            ORDER BY AVG(duration)/60 DESC""",mydb)'''
df1 = pd.read_sql_query("""SELECT channel_name, 
                        SUM(duration_sec) / COUNT(*) AS average_duration
                        FROM (
                            SELECT channel_name, 
                            CASE
                                WHEN duration REGEXP '^PT[0-9]+H[0-9]+M[0-9]+S$' THEN 
                                TIME_TO_SEC(CONCAT(
                                SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'H', 1), 'T', -1), ':',
                            SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'M', 1), 'H', -1), ':',
                            SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'S', 1), 'M', -1)
                            ))
                                WHEN duration REGEXP '^PT[0-9]+M[0-9]+S$' THEN 
                                TIME_TO_SEC(CONCAT(
                                '0:', SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'M', 1), 'T', -1), ':',
                                SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'S', 1), 'M', -1)
                            ))
                                WHEN duration REGEXP '^PT[0-9]+S$' THEN 
                                TIME_TO_SEC(CONCAT('0:0:', SUBSTRING_INDEX(SUBSTRING_INDEX(duration, 'S', 1), 'T', -1)))
                                END AS duration_sec
                        FROM video
                        ) AS subquery
                        GROUP BY channel_name""",mydb)
df1
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\2055638744.py:7: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#            channel_name  average_duration
# 0              Aji Arts               6.0
# 1       Lakshithakannan              21.0
# 2       Farester Vlog's              27.0
# 3          Divyalakshmi              39.0
# 4         Dheekshutimes              52.0
# 5  Mr and Mrs YuviDhivi              25.0
# 6          Sk Fit Feed               23.0
# 7          Zana samayal              34.0
# 8   Pink Pearls Chennai              74.0
# 9       Tharu's_passion               NaN

# %%
df = pd.read_sql_query("""SELECT channel_name,video_id,comment_count
                            FROM video
                            ORDER BY comment_count DESC
                            LIMIT 10""",mydb)
df
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_18008\3291171653.py:1: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#           channel_name     video_id  comment_count
# 0      Tharu's_passion  OMEAehSu3-g             55
# 1  Pink Pearls Chennai  Fo-Ckd9jQAw             20
# 2      Lakshithakannan  qIRiZBVZ1Jc              4
# 3         Divyalakshmi  o8fSEmtmrmY              4
# 4        Dheekshutimes  o_f8j1WGBhE              4
# 5        Dheekshutimes  o_f8j1WGBhE              4
# 6        Dheekshutimes  o_f8j1WGBhE              4
# 7        Dheekshutimes  o_f8j1WGBhE              4
# 8        Dheekshutimes  o_f8j1WGBhE              4
# 9        Dheekshutimes  o_f8j1WGBhE              4
